# %%
# Dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
days_to_close_csv = 'Resources_Clean/clean_median_days_to_close_week_all.csv'
days_pending_csv = 'Resources_Clean/clean_median_days_pending_week_all.csv'
sale_list_csv = 'Resources_Clean/clean_median_sale_to_list_week_all.csv'

sale_price_csv = 'Resources_Clean/clean_median_sale_price_week_all.csv'

days_to_close_df = pd.read_csv(days_to_close_csv)
days_to_pending_df = pd.read_csv(days_pending_csv)
sale_list_df = pd.read_csv(sale_list_csv)
sale_price_df = pd.read_csv(sale_price_csv)

# %%
days_to_close_df.head()
# Out:
#    Region ID  Size Rank    Region Name Region Type State Name        Date  \
# 0     102001          0  United States     country        NaN  2018-01-06
# 1     102001          0  United States     country        NaN  2018-01-13
# 2     102001          0  United States     country        NaN  2018-01-20
# 3     102001          0  United States     country        NaN  2018-01-27
# 4     102001          0  United States     country        NaN  2018-02-03
#
#    Median Days to Close  Median Days to Close Rolling Avg
# 0                  35.0                               NaN
# 1                  35.0                               NaN
# 2                  37.0                         35.666667
# 3                  35.0                         35.666667
# 4                  33.0                         35.000000

# %%
days_to_pending_df.head()
# Out:
#    Region ID  Size Rank   Region Name Region Type State Name        Date  \
# 0     394913          1  New York, NY         msa         NY  2018-01-06
# 1     394913          1  New York, NY         msa         NY  2018-01-13
# 2     394913          1  New York, NY         msa         NY  2018-01-20
# 3     394913          1  New York, NY         msa         NY  2018-01-27
# 4     394913          1  New York, NY         msa         NY  2018-02-03
#
#    Median Days Pending  Median Days Pending Rolling Avg
# 0                 84.0                              NaN
# 1                 87.0                              NaN
# 2                 86.0                        85.666667
# 3                 94.0                        89.000000
# 4                 78.0                        86.000000

# %%
sale_list_df.head()
# Out:
#    Region ID  Size Rank    Region Name Region Type State Name        Date  \
# 0     102001          0  United States     country        NaN  2018-01-06
# 1     102001          0  United States     country        NaN  2018-01-13
# 2     102001          0  United States     country        NaN  2018-01-20
# 3     102001          0  United States     country        NaN  2018-01-27
# 4     102001          0  United States     country        NaN  2018-02-03
#
#    Median Sale to List Ratio  Median Sale to List Ratio Rolling Avg
# 0                   0.982987                                    NaN
# 1                   0.982414                                    NaN
# 2                   0.981818                               0.982406
# 3                   0.981133                               0.981788
# 4                   0.980392                               0.981114

# %%
merged_df = pd.merge(days_to_close_df, days_to_pending_df, on=['Region Name', 'Date'])
merged_df = pd.merge(merged_df, sale_list_df, on=['Region Name', 'Date'])
merged_df
# Out:
#       Region ID_x  Size Rank_x      Region Name Region Type_x State Name_x  \
# 0          394913            1     New York, NY           msa           NY
# 1          394913            1     New York, NY           msa           NY
# 2          394913            1     New York, NY           msa           NY
# 3          394913            1     New York, NY           msa           NY
# 4          394913            1     New York, NY           msa           NY
# ...           ...          ...              ...           ...          ...
# 6617       395009          237  Punta Gorda, FL           msa           FL
# 6618       395009          237  Punta Gorda, FL           msa           FL
# 6619       395009          237  Punta Gorda, FL           msa           FL
# 6620       395009          237  Punta Gorda, FL           msa           FL
# 6621       395009          237  Punta Gorda, FL           msa           FL
#
#             Date  Median Days to Close  Median Days to Close Rolling Avg  \
# 0     2018-01-06                  62.0                               NaN
# 1     2018-01-13                  64.0                               NaN
# 2     2018-01-20                  61.0                         62.333333
# 3     2018-01-27                  62.0                         62.333333
# 4     2018-02-03                  58.0                         60.333333
# ...          ...                   ...                               ...
# 6617  2023-09-09                  33.0                         33.333333
# 6618  2023-09-16                  34.0                         33.666667
# 6619  2023-09-23                  34.0                         33.666667
# 6620  2023-09-30                  33.0                         33.666667
# 6621  2023-10-07                  28.0                         31.666667
#
#       Region ID_y  Size Rank_y Region Type_y State Name_y  \
# 0          394913            1           msa           NY
# 1          394913            1           msa           NY
# 2          394913            1           msa           NY
# 3          394913            1           msa           NY
# 4          394913            1           msa           NY
# ...           ...          ...           ...          ...
# 6617       395009          237           msa           FL
# 6618       395009          237           msa           FL
# 6619       395009          237           msa           FL
# 6620       395009          237           msa           FL
# 6621       395009          237           msa           FL
#
#       Median Days Pending  Median Days Pending Rolling Avg  Region ID  \
# 0                    84.0                              NaN     394913
# 1                    87.0                              NaN     394913
# 2                    86.0                        85.666667     394913
# 3                    94.0                        89.000000     394913
# 4                    78.0                        86.000000     394913
# ...                   ...                              ...        ...
# 6617                 44.0                        40.000000     395009
# 6618                 36.0                        39.000000     395009
# 6619                 41.0                        40.333333     395009
# 6620                 32.0                        36.333333     395009
# 6621                 39.0                        37.333333     395009
#
#       Size Rank Region Type State Name  Median Sale to List Ratio  \
# 0             1         msa         NY                   0.975123
# 1             1         msa         NY                   0.978865
# 2             1         msa         NY                   0.979016
# 3             1         msa         NY                   0.976478
# 4             1         msa         NY                   0.977842
# ...         ...         ...        ...                        ...
# 6617        237         msa         FL                   0.978987
# 6618        237         msa         FL                   0.971429
# 6619        237         msa         FL                   0.981456
# 6620        237         msa         FL                   0.971897
# 6621        237         msa         FL                   0.974141
#
#       Median Sale to List Ratio Rolling Avg
# 0                                       NaN
# 1                                       NaN
# 2                                  0.977668
# 3                                  0.978120
# 4                                  0.977779
# ...                                     ...
# 6617                               0.973453
# 6618                               0.974133
# 6619                               0.977290
# 6620                               0.974927
# 6621                               0.975831
#
# [6622 rows x 20 columns]

# %%
pending_salelist_df = pd.merge(sale_list_df, days_to_pending_df, on=['Region Name', 'Date'])
pending_salelist_df
# Out:
#        Region ID_x  Size Rank_x      Region Name Region Type_x State Name_x  \
# 0           394913            1     New York, NY           msa           NY
# 1           394913            1     New York, NY           msa           NY
# 2           394913            1     New York, NY           msa           NY
# 3           394913            1     New York, NY           msa           NY
# 4           394913            1     New York, NY           msa           NY
# ...            ...          ...              ...           ...          ...
# 10229       395009          237  Punta Gorda, FL           msa           FL
# 10230       395009          237  Punta Gorda, FL           msa           FL
# 10231       395009          237  Punta Gorda, FL           msa           FL
# 10232       395009          237  Punta Gorda, FL           msa           FL
# 10233       395009          237  Punta Gorda, FL           msa           FL
#
#              Date  Median Sale to List Ratio  \
# 0      2018-01-06                   0.975123
# 1      2018-01-13                   0.978865
# 2      2018-01-20                   0.979016
# 3      2018-01-27                   0.976478
# 4      2018-02-03                   0.977842
# ...           ...                        ...
# 10229  2023-09-09                   0.978987
# 10230  2023-09-16                   0.971429
# 10231  2023-09-23                   0.981456
# 10232  2023-09-30                   0.971897
# 10233  2023-10-07                   0.974141
#
#        Median Sale to List Ratio Rolling Avg  Region ID_y  Size Rank_y  \
# 0                                        NaN       394913            1
# 1                                        NaN       394913            1
# 2                                   0.977668       394913            1
# 3                                   0.978120       394913            1
# 4                                   0.977779       394913            1
# ...                                      ...          ...          ...
# 10229                               0.973453       395009          237
# 10230                               0.974133       395009          237
# 10231                               0.977290       395009          237
# 10232                               0.974927       395009          237
# 10233                               0.975831       395009          237
#
#       Region Type_y State Name_y  Median Days Pending  \
# 0               msa           NY                 84.0
# 1               msa           NY                 87.0
# 2               msa           NY                 86.0
# 3               msa           NY                 94.0
# 4               msa           NY                 78.0
# ...             ...          ...                  ...
# 10229           msa           FL                 44.0
# 10230           msa           FL                 36.0
# 10231           msa           FL                 41.0
# 10232           msa           FL                 32.0
# 10233           msa           FL                 39.0
#
#        Median Days Pending Rolling Avg
# 0                                  NaN
# 1                                  NaN
# 2                            85.666667
# 3                            89.000000
# 4                            86.000000
# ...                                ...
# 10229                        40.000000
# 10230                        39.000000
# 10231                        40.333333
# 10232                        36.333333
# 10233                        37.333333
#
# [10234 rows x 14 columns]

# %%
merged_reduced = merged_df[['Region ID_x',
                             'Size Rank_x',
                             'Region Name',
                             'Region Type_x',
                             'State Name_x',
                             'Date', 
                             'Median Days to Close',
                             'Median Days to Close Rolling Avg',
                             'Median Days Pending',
                             'Median Days Pending Rolling Avg',
                             'Median Sale to List Ratio',
                             'Median Sale to List Ratio Rolling Avg']]

merged_reduced = merged_reduced.rename(columns = {'Region ID_x':'Region Id',
                             'Size Rank_x':'Size Rank',
                             'Region Type_x':'Region Type',
                             'State Name_x':'State Name',
                             'Median Days Pending':'Median Days to Pending',
                             'Median Days Pending Rolling Avg':'Median Days to Pending Rolling Avg'})

merged_reduced
# Out:
#       Region Id  Size Rank      Region Name Region Type State Name  \
# 0        394913          1     New York, NY         msa         NY
# 1        394913          1     New York, NY         msa         NY
# 2        394913          1     New York, NY         msa         NY
# 3        394913          1     New York, NY         msa         NY
# 4        394913          1     New York, NY         msa         NY
# ...         ...        ...              ...         ...        ...
# 6617     395009        237  Punta Gorda, FL         msa         FL
# 6618     395009        237  Punta Gorda, FL         msa         FL
# 6619     395009        237  Punta Gorda, FL         msa         FL
# 6620     395009        237  Punta Gorda, FL         msa         FL
# 6621     395009        237  Punta Gorda, FL         msa         FL
#
#             Date  Median Days to Close  Median Days to Close Rolling Avg  \
# 0     2018-01-06                  62.0                               NaN
# 1     2018-01-13                  64.0                               NaN
# 2     2018-01-20                  61.0                         62.333333
# 3     2018-01-27                  62.0                         62.333333
# 4     2018-02-03                  58.0                         60.333333
# ...          ...                   ...                               ...
# 6617  2023-09-09                  33.0                         33.333333
# 6618  2023-09-16                  34.0                         33.666667
# 6619  2023-09-23                  34.0                         33.666667
# 6620  2023-09-30                  33.0                         33.666667
# 6621  2023-10-07                  28.0                         31.666667
#
#       Median Days to Pending  Median Days to Pending Rolling Avg  \
# 0                       84.0                                 NaN
# 1                       87.0                                 NaN
# 2                       86.0                           85.666667
# 3                       94.0                           89.000000
# 4                       78.0                           86.000000
# ...                      ...                                 ...
# 6617                    44.0                           40.000000
# 6618                    36.0                           39.000000
# 6619                    41.0                           40.333333
# 6620                    32.0                           36.333333
# 6621                    39.0                           37.333333
#
#       Median Sale to List Ratio  Median Sale to List Ratio Rolling Avg
# 0                      0.975123                                    NaN
# 1                      0.978865                                    NaN
# 2                      0.979016                               0.977668
# 3                      0.976478                               0.978120
# 4                      0.977842                               0.977779
# ...                         ...                                    ...
# 6617                   0.978987                               0.973453
# 6618                   0.971429                               0.974133
# 6619                   0.981456                               0.977290
# 6620                   0.971897                               0.974927
# 6621                   0.974141                               0.975831
#
# [6622 rows x 12 columns]

# %%
merged_reduced = merged_df[['Region ID_x',
                             'Size Rank_x',
                             'Region Name',
                             'Region Type_x',
                             'State Name_x',
                             'Date', 
                             'Median Days to Close',
                             'Median Days to Close Rolling Avg',
                             'Median Days Pending',
                             'Median Days Pending Rolling Avg',
                             'Median Sale to List Ratio',
                             'Median Sale to List Ratio Rolling Avg']]

merged_reduced = merged_reduced.rename(columns = {'Region ID_x':'Region Id',
                             'Size Rank_x':'Size Rank',
                             'Region Type_x':'Region Type',
                             'State Name_x':'State Name',
                             'Median Days Pending':'Median Days to Pending',
                             'Median Days Pending Rolling Avg':'Median Days to Pending Rolling Avg'})

merged_reduced
# Out:
#       Region Id  Size Rank      Region Name Region Type State Name  \
# 0        394913          1     New York, NY         msa         NY
# 1        394913          1     New York, NY         msa         NY
# 2        394913          1     New York, NY         msa         NY
# 3        394913          1     New York, NY         msa         NY
# 4        394913          1     New York, NY         msa         NY
# ...         ...        ...              ...         ...        ...
# 6617     395009        237  Punta Gorda, FL         msa         FL
# 6618     395009        237  Punta Gorda, FL         msa         FL
# 6619     395009        237  Punta Gorda, FL         msa         FL
# 6620     395009        237  Punta Gorda, FL         msa         FL
# 6621     395009        237  Punta Gorda, FL         msa         FL
#
#             Date  Median Days to Close  Median Days to Close Rolling Avg  \
# 0     2018-01-06                  62.0                               NaN
# 1     2018-01-13                  64.0                               NaN
# 2     2018-01-20                  61.0                         62.333333
# 3     2018-01-27                  62.0                         62.333333
# 4     2018-02-03                  58.0                         60.333333
# ...          ...                   ...                               ...
# 6617  2023-09-09                  33.0                         33.333333
# 6618  2023-09-16                  34.0                         33.666667
# 6619  2023-09-23                  34.0                         33.666667
# 6620  2023-09-30                  33.0                         33.666667
# 6621  2023-10-07                  28.0                         31.666667
#
#       Median Days to Pending  Median Days to Pending Rolling Avg  \
# 0                       84.0                                 NaN
# 1                       87.0                                 NaN
# 2                       86.0                           85.666667
# 3                       94.0                           89.000000
# 4                       78.0                           86.000000
# ...                      ...                                 ...
# 6617                    44.0                           40.000000
# 6618                    36.0                           39.000000
# 6619                    41.0                           40.333333
# 6620                    32.0                           36.333333
# 6621                    39.0                           37.333333
#
#       Median Sale to List Ratio  Median Sale to List Ratio Rolling Avg
# 0                      0.975123                                    NaN
# 1                      0.978865                                    NaN
# 2                      0.979016                               0.977668
# 3                      0.976478                               0.978120
# 4                      0.977842                               0.977779
# ...                         ...                                    ...
# 6617                   0.978987                               0.973453
# 6618                   0.971429                               0.974133
# 6619                   0.981456                               0.977290
# 6620                   0.971897                               0.974927
# 6621                   0.974141                               0.975831
#
# [6622 rows x 12 columns]

# %%
column_data_types = merged_reduced.dtypes
print(column_data_types)
# Out:
# Region Id                                  int64
# Size Rank                                  int64
# Region Name                               object
# Region Type                               object
# State Name                                object
# Date                                      object
# Median Days to Close                     float64
# Median Days to Close Rolling Avg         float64
# Median Days to Pending                   float64
# Median Days to Pending Rolling Avg       float64
# Median Sale to List Ratio                float64
# Median Sale to List Ratio Rolling Avg    float64
# dtype: object

# %%
merged_reduced['Date'] = pd.to_datetime(merged_reduced['Date'])

# %%
print(column_data_types)
# Out:
# Region Id                                  int64
# Size Rank                                  int64
# Region Name                               object
# Region Type                               object
# State Name                                object
# Date                                      object
# Median Days to Close                     float64
# Median Days to Close Rolling Avg         float64
# Median Days to Pending                   float64
# Median Days to Pending Rolling Avg       float64
# Median Sale to List Ratio                float64
# Median Sale to List Ratio Rolling Avg    float64
# dtype: object

# %%
merged_top_size = merged_reduced.loc[merged_reduced['Size Rank'] < 10]

# %%
merged_top_size.pivot(index='Date', columns='Region Name', values='Median Days to Pending').plot(kind='line')
merged_top_size.pivot
plt.title('Median Days to Pending Over Time by Region')
plt.xlabel('Date')
plt.ylabel('Median Days to Pending')
plt.legend(title='Region Name', bbox_to_anchor=(1.05, 1), loc='upper left')  # Adjust legend position
plt.show()

# %%
merged_top_size.pivot
# Out:
# <bound method DataFrame.pivot of       Region Id  Size Rank   Region Name Region Type State Name       Date  \
# 0        394913          1  New York, NY         msa         NY 2018-01-06
# 1        394913          1  New York, NY         msa         NY 2018-01-13
# 2        394913          1  New York, NY         msa         NY 2018-01-20
# 3        394913          1  New York, NY         msa         NY 2018-01-27
# 4        394913          1  New York, NY         msa         NY 2018-02-03
# ...         ...        ...           ...         ...        ...        ...
# 1199     394347          9   Atlanta, GA         msa         GA 2023-09-09
# 1200     394347          9   Atlanta, GA         msa         GA 2023-09-16
# 1201     394347          9   Atlanta, GA         msa         GA 2023-09-23
# 1202     394347          9   Atlanta, GA         msa         GA 2023-09-30
# 1203     394347          9   Atlanta, GA         msa         GA 2023-10-07
#
#       Median Days to Close  Median Days to Close Rolling Avg  \
# 0                     62.0                               NaN
# 1                     64.0                               NaN
# 2                     61.0                         62.333333
# 3                     62.0                         62.333333
# 4                     58.0                         60.333333
# ...                    ...                               ...
# 1199                  25.0                         24.666667
# 1200                  25.0                         25.000000
# 1201                  25.0                         25.000000
# 1202                  23.0                         24.333333
# 1203                  21.0                         23.000000
#
#       Median Days to Pending  Median Days to Pending Rolling Avg  \
# 0                       84.0                                 NaN
# 1                       87.0                                 NaN
# 2                       86.0                           85.666667
# 3                       94.0                           89.000000
# 4                       78.0                           86.000000
# ...                      ...                                 ...
# 1199                    18.0                           16.333333
# 1200                    17.0                           16.666667
# 1201                    18.0                           17.666667
# 1202                    19.0                           18.000000
# 1203                    19.0                           18.666667
#
#       Median Sale to List Ratio  Median Sale to List Ratio Rolling Avg
# 0                      0.975123                                    NaN
# 1                      0.978865                                    NaN
# 2                      0.979016                               0.977668
# 3                      0.976478                               0.978120
# 4                      0.977842                               0.977779
# ...                         ...                                    ...
# 1199                   1.000000                               1.000000
# 1200                   0.997096                               0.999032
# 1201                   0.998748                               0.998615
# 1202                   1.000000                               0.998615
# 1203                   0.994595                               0.997781
#
# [1204 rows x 12 columns]>

# %%
merged_top_size.pivot(index='Date', columns='Region Name', values='Median Days to Close').plot(kind='line')
plt.title('Median Days to Close Over Time by Region')
plt.xlabel('Date')
plt.ylabel('Median Days to Close')
plt.legend(title='Region Name', bbox_to_anchor=(1.05, 1), loc='upper left')  # Adjust legend position
plt.show()

# %%
merged_top_size.pivot(index='Date', columns='Region Name', values='Median Sale to List Ratio').plot(kind='line')
plt.title('Median Sale to List Ratio Over Time by Region')
plt.xlabel('Date')
plt.ylabel('Sale to List Ratio')
plt.legend(title='Region Name', bbox_to_anchor=(1.05, 1), loc='upper left')  # Adjust legend position
plt.show()

# %%
correlation = merged_reduced['Median Sale to List Ratio'].corr(merged_reduced['Median Days to Pending'])

print(f"Correlation between Median Sale to List Ratio and Median Days to Pending: {correlation}")
# Out:
# Correlation between Median Sale to List Ratio and Median Days to Pending: -0.6765766865370444

# %%
# Selecting columns for linear regression
x = merged_reduced['Median Days to Pending']
y = merged_reduced['Median Sale to List Ratio']

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Print the regression results
print(f"Slope: {slope}")
print(f"Intercept: {intercept}")
print(f"R-squared: {r_value**2}")
print(f"P-value: {p_value}")
print(f"Standard Error: {std_err}")
# Out:
# Slope: -0.0006044563387019152
# Intercept: 1.006819571774129
# R-squared: 0.45775601276544603
# P-value: 0.0
# Standard Error: 8.085675076362954e-06

# %%
# Selecting columns for linear regression
x = merged_reduced['Median Days to Close']
y = merged_reduced['Median Sale to List Ratio']

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Print the regression results
print(f"Slope: {slope}")
print(f"Intercept: {intercept}")
print(f"R-squared: {r_value**2}")
print(f"P-value: {p_value}")
print(f"Standard Error: {std_err}")
# Out:
# Slope: -0.00035162596567617476
# Intercept: 1.0051169295938156
# R-squared: 0.019750135670443644
# P-value: 1.4631576902110192e-30
# Standard Error: 3.0446354303849215e-05

# %%
plt.scatter(merged_reduced['Median Days to Pending'], merged_reduced['Median Sale to List Ratio'], alpha=0.5)
plt.title('Scatter Plot: Median Days to Pending vs. Median Sale to List Ratio')
plt.xlabel('Median Days to Pending')
plt.ylabel('Median Sale to List Ratio')
plt.show()

# %%
plt.scatter(merged_top_size['Median Days to Pending'], merged_top_size['Median Sale to List Ratio'], alpha=0.5)
plt.title('Scatter Plot: Median Days to Pending vs. Median Sale to List Ratio')
plt.xlabel('Median Days to Pending')
plt.ylabel('Median Sale to List Ratio')
plt.show()

# %%
plt.scatter(merged_top_size['Median Days to Close'], merged_top_size['Median Sale to List Ratio'], alpha=0.5)
plt.title('Scatter Plot: Median Days to Close vs. Median Sale to List Ratio')
plt.xlabel('Median Days to Close')
plt.ylabel('Median Sale to List Ratio')
plt.show()
