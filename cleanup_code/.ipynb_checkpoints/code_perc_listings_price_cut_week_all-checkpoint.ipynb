# %% [markdown]
# # Zillow CSV ETL process

# %% [markdown]
# This code serves as a blueprint for the csv ETL process. You will need to update certain field and column names in this report according to the csv file name, the metric and report under consideration, and so on. There are annotations provided throughout to guide you through the code.

# %%
# Dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# # Declare Variables

# %%
#Add inputs here, and clean csv should auto-populate
raw_csv_path = 'Resources_Raw/raw_perc_listings_price_cut_week_all.csv'
clean_csv_path = 'Resources_Clean/clean_perc_listings_price_cut_week_all.csv'
metric_name = 'Percent of Listings with Price Cut (%)'

# %%
initial_csv = Path(raw_csv_path)
initial_df = pd.read_csv(initial_csv)
initial_df
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2018-01-13  \
# 0      102001         0    United States    country       NaN    0.048289
# 1      394913         1     New York, NY        msa        NY    0.039355
# 2      753899         2  Los Angeles, CA        msa        CA    0.055506
# 3      394463         3      Chicago, IL        msa        IL    0.066376
# 4      394514         4       Dallas, TX        msa        TX    0.068313
# ..        ...       ...              ...        ...       ...         ...
# 921    753929       935       Zapata, TX        msa        TX         NaN
# 922    394743       936    Ketchikan, AK        msa        AK    0.000000
# 923    753874       937        Craig, CO        msa        CO    0.018868
# 924    395188       938       Vernon, TX        msa        TX         NaN
# 925    394767       939       Lamesa, TX        msa        TX         NaN
#
#      2018-01-20  2018-01-27  2018-02-03  2018-02-10  ...  2023-09-02  \
# 0      0.044279    0.047172    0.048079    0.047539  ...    0.084324
# 1      0.037057    0.037613    0.039435    0.036416  ...    0.033419
# 2      0.052349    0.050636    0.051697    0.054797  ...    0.059652
# 3      0.061356    0.062356    0.066945    0.055990  ...    0.084484
# 4      0.059395    0.061169    0.058698    0.058176  ...    0.125521
# ..          ...         ...         ...         ...  ...         ...
# 921         NaN         NaN         NaN         NaN  ...    0.000000
# 922    0.044776    0.015873    0.014925    0.046154  ...    0.069767
# 923    0.019802    0.020619    0.020000    0.000000  ...    0.107143
# 924         NaN         NaN         NaN         NaN  ...    0.173913
# 925         NaN         NaN         NaN         NaN  ...    0.026316
#
#      2023-09-09  2023-09-16  2023-09-23  2023-09-30  2023-10-07  2023-10-14  \
# 0      0.086064    0.091261    0.090410    0.090925    0.093965    0.091395
# 1      0.045924    0.046643    0.047027    0.044495    0.048608    0.048381
# 2      0.072151    0.066184    0.068562    0.066404    0.072646    0.072648
# 3      0.098833    0.105610    0.102903    0.097691    0.106043    0.104743
# 4      0.122744    0.126861    0.124637    0.126677    0.128565    0.130702
# ..          ...         ...         ...         ...         ...         ...
# 921    0.090909    0.000000    0.000000    0.000000    0.031250    0.000000
# 922    0.069767    0.000000    0.000000    0.090909    0.048780    0.023256
# 923    0.111111    0.080460    0.090909    0.097561    0.083333    0.050000
# 924    0.041667    0.066667    0.022222    0.041667    0.042553    0.021277
# 925    0.078947    0.138889    0.105263    0.024390    0.153846    0.026316
#
#      2023-10-21  2023-10-28  2023-11-04
# 0      0.092427    0.090298    0.091347
# 1      0.051134    0.049100    0.048564
# 2      0.073022    0.073210    0.077873
# 3      0.099614    0.097945    0.101734
# 4      0.123969    0.120726    0.122733
# ..          ...         ...         ...
# 921    0.000000    0.000000    0.031250
# 922    0.000000    0.025641    0.026316
# 923    0.023256    0.070588    0.083333
# 924    0.042553    0.000000    0.046512
# 925    0.076923    0.075000    0.050000
#
# [926 rows x 309 columns]

# %% [markdown]
# # Remove Nulls from DataFrame

# %%
#Checks if any Date column has a null for a given RegionName

#looks at column range from 6th column to last column in df
date_columns_slice = initial_df.iloc[:, 5:-1]

#looks at every row in this column range, and checks for null values
date_range_columns = initial_df.loc[:,date_columns_slice.columns] 
null_check = date_range_columns.isna().any(axis=1)

#Reverse filter based on null check for rows without null
null_check_df = initial_df.loc[~null_check, :]

#Preview
null_check_df
# Out:
#      RegionID  SizeRank         RegionName RegionType StateName  2018-01-13  \
# 10     394404        10         Boston, MA        msa        MA    0.049033
# 12     395057        12  San Francisco, CA        msa        CA    0.036474
# 15     395078        15        Seattle, WA        msa        WA    0.043327
# 19     394530        19         Denver, CO        msa        CO    0.064196
# 25     394998        25       Portland, OR        msa        OR    0.057681
# ..        ...       ...                ...        ...       ...         ...
# 916    394342       929       Atchison, KS        msa        KS    0.061538
# 917    753880       930      Fairfield, IA        msa        IA    0.037500
# 919    395142       933     Sweetwater, TX        msa        TX    0.047619
# 922    394743       936      Ketchikan, AK        msa        AK    0.000000
# 923    753874       937          Craig, CO        msa        CO    0.018868
#
#      2018-01-20  2018-01-27  2018-02-03  2018-02-10  ...  2023-09-02  \
# 10     0.044170    0.051038    0.040278    0.048458  ...    0.050164
# 12     0.032407    0.033843    0.033382    0.033367  ...    0.062790
# 15     0.046030    0.048041    0.043121    0.041709  ...    0.098580
# 19     0.055839    0.054809    0.053516    0.061648  ...    0.116740
# 25     0.064190    0.057951    0.061347    0.065369  ...    0.095273
# ..          ...         ...         ...         ...  ...         ...
# 916    0.000000    0.045455    0.046875    0.016667  ...    0.081081
# 917    0.000000    0.054054    0.013158    0.014085  ...    0.055556
# 919    0.046875    0.015152    0.045455    0.015873  ...    0.077922
# 922    0.044776    0.015873    0.014925    0.046154  ...    0.069767
# 923    0.019802    0.020619    0.020000    0.000000  ...    0.107143
#
#      2023-09-09  2023-09-16  2023-09-23  2023-09-30  2023-10-07  2023-10-14  \
# 10     0.083053    0.072985    0.076442    0.085019    0.093112    0.084211
# 12     0.073843    0.062848    0.072275    0.079922    0.073457    0.082736
# 15     0.111283    0.100682    0.115015    0.108280    0.110224    0.105052
# 19     0.133076    0.136877    0.131124    0.138791    0.140880    0.135334
# 25     0.118846    0.108591    0.103183    0.104925    0.124729    0.103104
# ..          ...         ...         ...         ...         ...         ...
# 916    0.050000    0.083333    0.130435    0.155556    0.046512    0.062500
# 917    0.092593    0.092593    0.035088    0.064516    0.096774    0.048387
# 919    0.044118    0.082192    0.111111    0.028169    0.120000    0.053333
# 922    0.069767    0.000000    0.000000    0.090909    0.048780    0.023256
# 923    0.111111    0.080460    0.090909    0.097561    0.083333    0.050000
#
#      2023-10-21  2023-10-28  2023-11-04
# 10     0.086264    0.083706    0.088549
# 12     0.083429    0.077043    0.073653
# 15     0.117421    0.104387    0.110932
# 19     0.132998    0.116328    0.111021
# 25     0.099639    0.104687    0.106281
# ..          ...         ...         ...
# 916    0.125000    0.133333    0.023256
# 917    0.103448    0.118644    0.086207
# 919    0.025974    0.040541    0.026667
# 922    0.000000    0.025641    0.026316
# 923    0.023256    0.070588    0.083333
#
# [341 rows x 309 columns]

# %% [markdown]
# # Condense Date Columns to Single Column

# %% [markdown]
# In this section, we condense the multiple date columns into a single 'date' column. This allows for easier data visualization moving forward.

# %%
condensed_rough_df = pd.DataFrame(null_check_df)

new_rows = []

#For loop to iterate through each RegionName
for _, row in condensed_rough_df.iterrows():
    region_ID = row['RegionID']
    size_rank = row['SizeRank']
    region_name = row['RegionName']
    region_type = row['RegionType']
    state_name = row['StateName']
    
    #For loop to iterate through each Date Column within a given RegionName
    for date_column in condensed_rough_df.columns[5:]:
        date = pd.to_datetime(date_column)
        value = row[date_column]
        
        #Add 'Date' and 'value' values for a given Date and Region into new_rows list.
        new_rows.append([region_ID,size_rank,region_name,region_type,state_name, date, value])

#New df based on new_rows 'list'
condensed_df = pd.DataFrame(new_rows, columns=
                             ['Region ID',
                              'Size Rank',
                              'Region Name',
                              'Region Type',
                              'State Name',
                              'Date',
                              metric_name])


#create moving average column for each Region.
window_size = 3 #time period (weeks)
condensed_df[f'{metric_name} Rolling Avg'] = condensed_df.groupby('Region Name')[metric_name].rolling(window=window_size).mean().reset_index(level=0, drop=True)

#preview df
condensed_df
# Out:
#         Region ID  Size Rank Region Name Region Type State Name       Date  \
# 0          394404         10  Boston, MA         msa         MA 2018-01-13
# 1          394404         10  Boston, MA         msa         MA 2018-01-20
# 2          394404         10  Boston, MA         msa         MA 2018-01-27
# 3          394404         10  Boston, MA         msa         MA 2018-02-03
# 4          394404         10  Boston, MA         msa         MA 2018-02-10
# ...           ...        ...         ...         ...        ...        ...
# 103659     753874        937   Craig, CO         msa         CO 2023-10-07
# 103660     753874        937   Craig, CO         msa         CO 2023-10-14
# 103661     753874        937   Craig, CO         msa         CO 2023-10-21
# 103662     753874        937   Craig, CO         msa         CO 2023-10-28
# 103663     753874        937   Craig, CO         msa         CO 2023-11-04
#
#         Percent of Listings with Price Cut (%)  \
# 0                                     0.049033
# 1                                     0.044170
# 2                                     0.051038
# 3                                     0.040278
# 4                                     0.048458
# ...                                        ...
# 103659                                0.083333
# 103660                                0.050000
# 103661                                0.023256
# 103662                                0.070588
# 103663                                0.083333
#
#         Percent of Listings with Price Cut (%) Rolling Avg
# 0                                                     NaN
# 1                                                     NaN
# 2                                                0.048080
# 3                                                0.045162
# 4                                                0.046592
# ...                                                   ...
# 103659                                           0.090601
# 103660                                           0.076965
# 103661                                           0.052196
# 103662                                           0.047948
# 103663                                           0.059059
#
# [103664 rows x 8 columns]

# %% [markdown]
# # Analysis Testing

# %% [markdown]
# Section I created to test initial clean dataframe. Use only as a referance for chart output.

# %%
MSA_filter = ['United States','New York, NY','Los Angeles, CA','Chicago, IL','Dallas, TX']

short_table = condensed_df['Region Name'].isin(MSA_filter)
filtered_df = condensed_df[short_table]

filtered_df
# Out:
#      Region ID  Size Rank Region Name Region Type State Name       Date  \
# 0       394404         10  Boston, MA         msa         MA 2018-01-13
# 1       394404         10  Boston, MA         msa         MA 2018-01-20
# 2       394404         10  Boston, MA         msa         MA 2018-01-27
# 3       394404         10  Boston, MA         msa         MA 2018-02-03
# 4       394404         10  Boston, MA         msa         MA 2018-02-10
# ..         ...        ...         ...         ...        ...        ...
# 299     394404         10  Boston, MA         msa         MA 2023-10-07
# 300     394404         10  Boston, MA         msa         MA 2023-10-14
# 301     394404         10  Boston, MA         msa         MA 2023-10-21
# 302     394404         10  Boston, MA         msa         MA 2023-10-28
# 303     394404         10  Boston, MA         msa         MA 2023-11-04
#
#      Percent of Listings with Price Cut (%)  \
# 0                                  0.049033
# 1                                  0.044170
# 2                                  0.051038
# 3                                  0.040278
# 4                                  0.048458
# ..                                      ...
# 299                                0.093112
# 300                                0.084211
# 301                                0.086264
# 302                                0.083706
# 303                                0.088549
#
#      Percent of Listings with Price Cut (%) Rolling Avg
# 0                                                  NaN
# 1                                                  NaN
# 2                                             0.048080
# 3                                             0.045162
# 4                                             0.046592
# ..                                                 ...
# 299                                           0.084858
# 300                                           0.087447
# 301                                           0.087862
# 302                                           0.084727
# 303                                           0.086173
#
# [304 rows x 8 columns]

# %%
window_size = 3

for region, data in filtered_df.groupby('Region Name'):
    data.plot(kind='line', x='Date', y=metric_name, label=f'{region} - Original', figsize=(10, 6))
    plt.plot(data['Date'], data[f'{metric_name} Rolling Avg'], label=f'{region} - Moving Average')

    
plt.title('Line Chart with Moving Average by Region')
plt.xlabel('Month')
plt.ylabel(metric_name)
plt.legend()
plt.show()

# %% [markdown]
# # Generate Clean CSV File

# %%
#IMPORTANT -- CHANGE CSV OUTPUT NAME RELEVANT REPORT
condensed_df.to_csv(clean_csv_path, index=False)
