# %% [markdown]
# # Zillow CSV ETL process

# %% [markdown]
# This code serves as a blueprint for the csv ETL process. You will need to update certain field and column names in this report according to the csv file name, the metric and report under consideration, and so on. There are annotations provided throughout to guide you through the code.

# %%
# Dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# # Declare Variables

# %%
#Add inputs here, and clean csv should auto-populate
start_date = '2018-01-06'
end_date = '2023-11-04'
raw_csv_path = 'Resources_Raw/raw_median_days_pending_week_all.csv'
clean_csv_path = 'Resources_Clean/clean_median_days_pending_week_all.csv'
metric_name = 'Median Days Pending'

# %%
initial_csv = Path(raw_csv_path)
initial_df = pd.read_csv(initial_csv)
initial_df
# Out:
#      RegionID  SizeRank         RegionName RegionType StateName  2018-01-06  \
# 0      102001         0      United States    country       NaN        55.0
# 1      394913         1       New York, NY        msa        NY        84.0
# 2      753899         2    Los Angeles, CA        msa        CA        34.0
# 3      394463         3        Chicago, IL        msa        IL        73.0
# 4      394514         4         Dallas, TX        msa        TX        41.0
# ..        ...       ...                ...        ...       ...         ...
# 292    394345       446         Athens, TX        msa        TX         NaN
# 293    394674       467          Heber, UT        msa        UT         NaN
# 294    394593       470        Findlay, OH        msa        OH         NaN
# 295    394877       491  Morehead City, NC        msa        NC         NaN
# 296    394411       561        Branson, MO        msa        MO         NaN
#
#      2018-01-13  2018-01-20  2018-01-27  2018-02-03  ...  2023-09-02  \
# 0          51.0        46.0        44.0        35.0  ...        14.0
# 1          87.0        86.0        94.0        78.0  ...        26.0
# 2          30.0        18.0        16.0        15.0  ...        14.0
# 3          62.0        59.0        55.0        37.0  ...         9.0
# 4          40.0        39.0        35.0        27.0  ...        19.0
# ..          ...         ...         ...         ...  ...         ...
# 292         NaN         NaN         NaN         NaN  ...         NaN
# 293         NaN         NaN         NaN         NaN  ...        26.0
# 294         NaN         NaN         NaN         NaN  ...         NaN
# 295         NaN         NaN         NaN         NaN  ...         NaN
# 296         NaN         NaN         NaN         NaN  ...         NaN
#
#      2023-09-09  2023-09-16  2023-09-23  2023-09-30  2023-10-07  2023-10-14  \
# 0          16.0        14.0        14.0        15.0        16.0        16.0
# 1          29.0        29.0        26.0        25.0        26.0        27.0
# 2          16.0        15.0        16.0        15.0        15.0        15.0
# 3          11.0         9.0         9.0        11.0        10.0        10.0
# 4          19.0        18.0        21.0        21.0        20.0        18.0
# ..          ...         ...         ...         ...         ...         ...
# 292         NaN         NaN         NaN         NaN         NaN         NaN
# 293        57.0        60.0        43.0        67.0        31.0        40.0
# 294         NaN         NaN         NaN         NaN         NaN         NaN
# 295         NaN         NaN         NaN         NaN         NaN         NaN
# 296         NaN         NaN         NaN         NaN         NaN         NaN
#
#      2023-10-21  2023-10-28  2023-11-04
# 0          16.0        17.0        19.0
# 1          28.0        26.0        27.0
# 2          17.0        15.0        15.0
# 3          12.0        12.0        13.0
# 4          22.0        19.0        23.0
# ..          ...         ...         ...
# 292         NaN         NaN        75.0
# 293        63.0        55.0        30.0
# 294         NaN         NaN        42.0
# 295         NaN         NaN         9.0
# 296         NaN         NaN        17.0
#
# [297 rows x 310 columns]

# %% [markdown]
# # Remove Nulls from DataFrame

# %%
#Checks if any Date column has a null for a given RegionName
date_range_columns = initial_df.loc[:, start_date : end_date] 
null_check = date_range_columns.isna().any(axis=1)

#Reverse filter based on null check for rows without null
null_check_df = initial_df.loc[~null_check, :]

#Preview
null_check_df
# Out:
#      RegionID  SizeRank              RegionName RegionType StateName  \
# 1      394913         1            New York, NY        msa        NY
# 2      753899         2         Los Angeles, CA        msa        CA
# 3      394463         3             Chicago, IL        msa        IL
# 5      394692         5             Houston, TX        msa        TX
# 8      394856         8               Miami, FL        msa        FL
# 9      394347         9             Atlanta, GA        msa        GA
# 11     394976        11             Phoenix, AZ        msa        AZ
# 13     395025        13           Riverside, CA        msa        CA
# 14     394532        14             Detroit, MI        msa        MI
# 16     394865        16         Minneapolis, MN        msa        MN
# 23     394458        23           Charlotte, NC        msa        NC
# 25     394998        25            Portland, OR        msa        OR
# 26     395045        26          Sacramento, CA        msa        CA
# 30     394775        30           Las Vegas, NV        msa        NV
# 33     394705        34        Indianapolis, IN        msa        IN
# 34     394475        35           Cleveland, OH        msa        OH
# 38     395005        39          Providence, RI        msa        RI
# 39     394714        40        Jacksonville, FL        msa        FL
# 75     394648        76          Greensboro, NC        msa        NC
# 76     395134        77            Stockton, CA        msa        CA
# 77     394440        78          Cape Coral, FL        msa        FL
# 82     394304        83               Akron, OH        msa        OH
# 83     394531        84          Des Moines, IA        msa        IA
# 88     395235        89             Winston, NC        msa        NC
# 96     394957        97            Palm Bay, FL        msa        FL
# 102    394871       103             Modesto, CA        msa        CA
# 105    395245       106          Youngstown, OH        msa        OH
# 106    394770       107             Lansing, MI        msa        MI
# 107    394589       109        Fayetteville, NC        msa        NC
# 116    395116       118         Springfield, MO        msa        MO
# 132    394972       136              Peoria, IL        msa        IL
# 133    394439       137              Canton, OH        msa        OH
# 134    395070       138            Savannah, GA        msa        GA
# 140    394520       144           Davenport, IA        msa        IL
# 141    395146       145         Tallahassee, FL        msa        FL
# 143    394901       147              Naples, FL        msa        FL
# 186    394609       196          Fort Smith, AR        msa        AR
# 187    845160       198     Prescott Valley, AZ        msa        AZ
# 201    394681       216  Hilton Head Island, SC        msa        SC
# 216    395009       237         Punta Gorda, FL        msa        FL
#
#      2018-01-06  2018-01-13  2018-01-20  2018-01-27  2018-02-03  ...  \
# 1          84.0        87.0        86.0        94.0        78.0  ...
# 2          34.0        30.0        18.0        16.0        15.0  ...
# 3          73.0        62.0        59.0        55.0        37.0  ...
# 5          45.0        43.0        43.0        39.0        29.0  ...
# 8          52.0        49.0        53.0        52.0        48.0  ...
# 9          36.0        33.0        29.0        21.0        18.0  ...
# 11         41.0        38.0        36.0        30.0        29.0  ...
# 13         39.0        35.0        31.0        23.0        23.0  ...
# 14         49.0        41.0        37.0        35.0        24.0  ...
# 16         50.0        54.0        38.0        40.0        23.0  ...
# 23         29.0        23.0        18.0        15.0        14.0  ...
# 25         42.0        30.0        28.0        19.0        16.0  ...
# 26         31.0        24.0        15.0        13.0        13.0  ...
# 30         44.0        39.0        35.0        40.0        54.0  ...
# 33         53.0        38.0        48.0        34.0        26.0  ...
# 34         61.0        80.0        61.0        69.0        61.0  ...
# 38         56.0        52.0        75.0        56.0        25.0  ...
# 140         7.0        12.0         8.0         7.0        12.0        10.0
# 141        12.0        14.0        11.0         7.0        12.0        13.0
# 143        41.0        28.0        33.0        29.0        30.0        34.0
# 186        33.0        20.0        26.0        23.0        15.0        23.0
# 187        37.0        12.0        26.0        29.0        24.0        46.0
# 201        14.0        16.0        14.0        24.0        24.0        24.0
# 216        37.0        44.0        36.0        41.0        32.0        39.0
#
#      2023-10-14  2023-10-21  2023-10-28  2023-11-04
# 1          27.0        28.0        26.0        27.0
# 2          15.0        17.0        15.0        15.0
# 3          10.0        12.0        12.0        13.0
# 5          24.0        22.0        26.0        27.0
# 8          24.0        23.0        23.0        29.0
# 9          21.0        21.0        22.0        24.0
# 11         21.0        22.0        25.0        25.0
# 13         19.0        19.0        18.0        21.0
# 14         10.0        11.0        13.0        11.0
# 16         22.0        23.0        23.0        26.0
# 23         13.0        10.0        11.0        15.0
# 25         17.0        19.0        26.0        26.0
# 26         12.0        15.0        16.0        14.0
# 30         16.0        20.0        16.0        21.0
# 33         12.0        13.0        14.0        15.0
# 34          8.0         9.0        11.0         9.0
# 38         10.0         9.0        10.0        12.0
# 39         31.0        36.0        39.0        34.0
# 75         11.0        13.0        11.0        12.0
# 76         15.0        14.0        20.0        15.0
# 77         34.0        36.0        29.0        34.0
# 82          8.0         9.0         8.0        10.0
# 83         13.0        15.0        15.0        18.0
# 88         11.0        10.0        11.0        15.0
# 96         24.0        21.0        20.0        33.0
# 102        11.0        13.0        16.0        16.0
# 105         8.0        11.0        18.0        12.0
# 106        10.0         8.0         7.0        11.0
# 107        11.0        11.0        10.0        12.0
# 116         8.0        15.0        19.0        21.0
# 132         5.0         7.0        10.0        12.0
# 133         6.0         9.0         8.0        11.0
# 134        18.0        18.0        19.0        22.0
# 140         7.0         7.0        15.0        13.0
# 141        11.0        14.0        30.0        12.0
# 143        35.0        33.0        30.0        27.0
# 186        26.0        27.0        10.0        19.0
# 187        21.0        35.0        20.0        53.0
# 201        18.0        17.0        26.0        22.0
# 216        35.0        32.0        33.0        35.0
#
# [40 rows x 310 columns]

# %% [markdown]
# # Condense Date Columns to Single Column

# %% [markdown]
# In this section, we condense the multiple date columns into a single 'date' column. This allows for easier data visualization moving forward.

# %%
condensed_rough_df = pd.DataFrame(null_check_df)

new_rows = []

#For loop to iterate through each RegionName
for _, row in condensed_rough_df.iterrows():
    region_ID = row['RegionID']
    size_rank = row['SizeRank']
    region_name = row['RegionName']
    region_type = row['RegionType']
    state_name = row['StateName']
    
    #For loop to iterate through each Date Column within a given RegionName
    for date_column in condensed_rough_df.columns[5:]:
        date = pd.to_datetime(date_column)
        value = row[date_column]
        
        #Add 'Date' and 'value' values for a given Date and Region into new_rows list.
        new_rows.append([region_ID,size_rank,region_name,region_type,state_name, date, value])

#New df based on new_rows 'list'
condensed_df = pd.DataFrame(new_rows, columns=
                             ['Region ID',
                              'Size Rank',
                              'Region Name',
                              'Region Type',
                              'State Name',
                              'Date',
                              metric_name])


#create moving average column for each Region.
window_size = 3 #time period (weeks)
condensed_df[f'{metric_name} Rolling Avg'] = condensed_df.groupby('Region Name')[metric_name].rolling(window=window_size).mean().reset_index(level=0, drop=True)

#preview df
condensed_df
# Out:
#        Region ID  Size Rank      Region Name Region Type State Name  \
# 0         394913          1     New York, NY         msa         NY
# 1         394913          1     New York, NY         msa         NY
# 2         394913          1     New York, NY         msa         NY
# 3         394913          1     New York, NY         msa         NY
# 4         394913          1     New York, NY         msa         NY
# ...          ...        ...              ...         ...        ...
# 12195     395009        237  Punta Gorda, FL         msa         FL
# 12196     395009        237  Punta Gorda, FL         msa         FL
# 12197     395009        237  Punta Gorda, FL         msa         FL
# 12198     395009        237  Punta Gorda, FL         msa         FL
# 12199     395009        237  Punta Gorda, FL         msa         FL
#
#             Date  Median Days Pending  Median Days Pending Rolling Avg
# 0     2018-01-06                 84.0                              NaN
# 1     2018-01-13                 87.0                              NaN
# 2     2018-01-20                 86.0                        85.666667
# 3     2018-01-27                 94.0                        89.000000
# 4     2018-02-03                 78.0                        86.000000
# ...          ...                  ...                              ...
# 12195 2023-10-07                 39.0                        37.333333
# 12196 2023-10-14                 35.0                        35.333333
# 12197 2023-10-21                 32.0                        35.333333
# 12198 2023-10-28                 33.0                        33.333333
# 12199 2023-11-04                 35.0                        33.333333
#
# [12200 rows x 8 columns]

# %% [markdown]
# # Analysis Testing

# %% [markdown]
# Section I created to test initial clean dataframe. Use only as a referance for chart output.

# %%
MSA_filter = ['United States','New York, NY','Los Angeles, CA','Chicago, IL','Dallas, TX']

short_table = condensed_df['Region Name'].isin(MSA_filter)
filtered_df = condensed_df[short_table]

filtered_df
# Out:
#      Region ID  Size Rank   Region Name Region Type State Name       Date  \
# 0       394913          1  New York, NY         msa         NY 2018-01-06
# 1       394913          1  New York, NY         msa         NY 2018-01-13
# 2       394913          1  New York, NY         msa         NY 2018-01-20
# 3       394913          1  New York, NY         msa         NY 2018-01-27
# 4       394913          1  New York, NY         msa         NY 2018-02-03
# ..         ...        ...           ...         ...        ...        ...
# 910     394463          3   Chicago, IL         msa         IL 2023-10-07
# 911     394463          3   Chicago, IL         msa         IL 2023-10-14
# 912     394463          3   Chicago, IL         msa         IL 2023-10-21
# 913     394463          3   Chicago, IL         msa         IL 2023-10-28
# 914     394463          3   Chicago, IL         msa         IL 2023-11-04
#
#      Median Days Pending  Median Days Pending Rolling Avg
# 0                   84.0                              NaN
# 1                   87.0                              NaN
# 2                   86.0                        85.666667
# 3                   94.0                        89.000000
# 4                   78.0                        86.000000
# ..                   ...                              ...
# 910                 10.0                        10.000000
# 911                 10.0                        10.333333
# 912                 12.0                        10.666667
# 913                 12.0                        11.333333
# 914                 13.0                        12.333333
#
# [915 rows x 8 columns]

# %%
window_size = 3

for region, data in filtered_df.groupby('Region Name'):
    data.plot(kind='line', x='Date', y=metric_name, label=f'{region} - Original', figsize=(10, 6))
    plt.plot(data['Date'], data[f'{metric_name} Rolling Avg'], label=f'{region} - Moving Average')

    
plt.title('Line Chart with Moving Average by Region')
plt.xlabel('Month')
plt.ylabel(metric_name)
plt.legend()
plt.show()

# %% [markdown]
# # Generate Clean CSV File

# %%
#IMPORTANT -- CHANGE CSV OUTPUT NAME RELEVANT REPORT
condensed_df.to_csv(clean_csv_path, index=False)
