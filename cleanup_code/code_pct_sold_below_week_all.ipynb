# %% [markdown]
# # Zillow CSV ETL process

# %% [markdown]
# This code serves as a blueprint for the csv ETL process. You will need to update certain field and column names in this report according to the csv file name, the metric and report under consideration, and so on. There are annotations provided throughout to guide you through the code.

# %%
# Dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# # Declare Variables

# %%
#Add inputs here, and clean csv should auto-populate
raw_csv_path = 'Resources_Raw/raw_pct_sold_below_week_all.csv'
clean_csv_path = 'Resources_Clean/clean_pct_sold_below_week_all.csv'
metric_name = 'Units Sold Below List Price (%)'

# %%
initial_csv = Path(raw_csv_path)
initial_df = pd.read_csv(initial_csv)
initial_df
# Out:
#      RegionID  SizeRank        RegionName RegionType StateName    1/6/18  \
# 0      102001         0     United States    country       NaN  0.633396
# 1      394913         1      New York, NY        msa        NY  0.691964
# 2      753899         2   Los Angeles, CA        msa        CA  0.474920
# 3      394463         3       Chicago, IL        msa        IL  0.761349
# 4      394514         4        Dallas, TX        msa        TX  0.599271
# ..        ...       ...               ...        ...       ...       ...
# 220    395086       402   Sevierville, TN        msa        TN       NaN
# 221    394410       408      Brainerd, MN        msa        MN       NaN
# 222    394928       410    Ocean City, NJ        msa        NJ       NaN
# 223    394674       467         Heber, UT        msa        UT       NaN
# 224    753871       811  Breckenridge, CO        msa        CO       NaN
#
#       1/13/18   1/20/18   1/27/18    2/3/18  ...    8/5/23   8/12/23  \
# 0    0.642037  0.648973  0.655017  0.660971  ...  0.440796  0.441613
# 1    0.677463  0.657895  0.709677  0.680745  ...  0.343321  0.371239
# 2    0.500825  0.500924  0.536302  0.502934  ...  0.330947  0.301235
# 3    0.768078  0.771457  0.770813  0.769055  ...  0.375136  0.388927
# 4    0.612551  0.584955  0.603471  0.571856  ...  0.507826  0.506305
# ..        ...       ...       ...       ...  ...       ...       ...
# 220       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 221       NaN       NaN       NaN       NaN  ...  0.378378  0.500000
# 222       NaN       NaN       NaN       NaN  ...  0.632653  0.666667
# 223       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 224       NaN       NaN       NaN       NaN  ...  0.884615  0.809524
#
#       8/19/23   8/26/23    9/2/23    9/9/23   9/16/23   9/23/23   9/30/23  \
# 0    0.447074  0.452579  0.457895  0.470099  0.470942  0.476891  0.479931
# 1    0.331229  0.357424  0.334816  0.337812  0.349560  0.368479  0.366373
# 2    0.310152  0.311216  0.321532  0.369149  0.339559  0.347076  0.369219
# 3    0.411243  0.409178  0.402941  0.420436  0.407202  0.434690  0.440529
# 4    0.535780  0.520388  0.517018  0.538569  0.531646  0.537181  0.555657
# ..        ...       ...       ...       ...       ...       ...       ...
# 220       NaN       NaN       NaN       NaN       NaN       NaN  0.666667
# 221  0.558824  0.411765  0.403846  0.472222  0.545455  0.540541  0.300000
# 222  0.653846  0.627907  0.719298  0.510204  0.571429  0.645833  0.534247
# 223       NaN       NaN  0.823529  0.760000  0.800000  0.851852  0.735294
# 224  0.548387  0.666667  0.758621  0.818182  0.655172  0.689655  0.594595
#
#       10/7/23
# 0    0.488763
# 1    0.400958
# 2    0.374768
# 3    0.438440
# 4    0.565510
# ..        ...
# 220  0.709677
# 221  0.451613
# 222  0.352941
# 223  0.782609
# 224  0.814815
#
# [225 rows x 306 columns]

# %% [markdown]
# # Remove Nulls from DataFrame

# %%
#Checks if any Date column has a null for a given RegionName

#looks at column range from 6th column to last column in df
date_columns_slice = initial_df.iloc[:, 5:-1]

#looks at every row in this column range, and checks for null values
date_range_columns = initial_df.loc[:,date_columns_slice.columns] 
null_check = date_range_columns.isna().any(axis=1)

#Reverse filter based on null check for rows without null
null_check_df = initial_df.loc[~null_check, :]

#Preview
null_check_df
# Out:
#      RegionID  SizeRank             RegionName RegionType StateName    1/6/18  \
# 0      102001         0          United States    country       NaN  0.633396
# 1      394913         1           New York, NY        msa        NY  0.691964
# 2      753899         2        Los Angeles, CA        msa        CA  0.474920
# 3      394463         3            Chicago, IL        msa        IL  0.761349
# 4      394514         4             Dallas, TX        msa        TX  0.599271
# ..        ...       ...                    ...        ...       ...       ...
# 174    845160       198    Prescott Valley, AZ        msa        AZ  0.675000
# 176    394361       202    Barnstable Town, MA        msa        MA  0.717949
# 193    394380       232               Bend, OR        msa        OR  0.611111
# 196    395009       237        Punta Gorda, FL        msa        FL  0.900000
# 210    394685       289  Homosassa Springs, FL        msa        FL  0.772727
#
#       1/13/18   1/20/18   1/27/18    2/3/18  ...    8/5/23   8/12/23  \
# 0    0.642037  0.648973  0.655017  0.660971  ...  0.440796  0.441613
# 1    0.677463  0.657895  0.709677  0.680745  ...  0.343321  0.371239
# 2    0.500825  0.500924  0.536302  0.502934  ...  0.330947  0.301235
# 3    0.768078  0.771457  0.770813  0.769055  ...  0.375136  0.388927
# 4    0.612551  0.584955  0.603471  0.571856  ...  0.507826  0.506305
# ..        ...       ...       ...       ...  ...       ...       ...
# 174  0.745098  0.653846  0.719298  0.725806  ...  0.515152  0.475410
# 176  0.812500  0.792453  0.773585  0.823529  ...  0.540541  0.346939
# 193  0.542857  0.620690  0.555556  0.574468  ...  0.363636  0.619048
# 196  0.870968  0.725000  0.757576  0.756757  ...  0.705263  0.706897
# 210  0.837838  0.780488  0.781250  0.886792  ...  0.681818  0.763158
#
#       8/19/23   8/26/23    9/2/23    9/9/23   9/16/23   9/23/23   9/30/23  \
# 0    0.447074  0.452579  0.457895  0.470099  0.470942  0.476891  0.479931
# 1    0.331229  0.357424  0.334816  0.337812  0.349560  0.368479  0.366373
# 2    0.310152  0.311216  0.321532  0.369149  0.339559  0.347076  0.369219
# 3    0.411243  0.409178  0.402941  0.420436  0.407202  0.434690  0.440529
# 4    0.535780  0.520388  0.517018  0.538569  0.531646  0.537181  0.555657
# ..        ...       ...       ...       ...       ...       ...       ...
# 174  0.646154  0.571429  0.714286  0.610169  0.514706  0.741379  0.707692
# 176  0.450000  0.507692  0.333333  0.522727  0.435484  0.470588  0.440000
# 193  0.611111  0.676056  0.687500  0.514286  0.537313  0.645833  0.622642
# 196  0.756410  0.752809  0.769231  0.702381  0.775281  0.702128  0.729167
# 210  0.654545  0.649123  0.684211  0.750000  0.657143  0.659574  0.672414
#
#       10/7/23
# 0    0.488763
# 1    0.400958
# 2    0.374768
# 3    0.438440
# 4    0.565510
# ..        ...
# 174  0.545455
# 176  0.478723
# 193  0.690909
# 196  0.703125
# 210  0.690476
#
# [95 rows x 306 columns]

# %% [markdown]
# # Condense Date Columns to Single Column

# %% [markdown]
# In this section, we condense the multiple date columns into a single 'date' column. This allows for easier data visualization moving forward.

# %%
condensed_rough_df = pd.DataFrame(null_check_df)

new_rows = []

#For loop to iterate through each RegionName
for _, row in condensed_rough_df.iterrows():
    region_ID = row['RegionID']
    size_rank = row['SizeRank']
    region_name = row['RegionName']
    region_type = row['RegionType']
    state_name = row['StateName']
    
    #For loop to iterate through each Date Column within a given RegionName
    for date_column in condensed_rough_df.columns[5:]:
        date = pd.to_datetime(date_column)
        value = row[date_column]
        
        #Add 'Date' and 'value' values for a given Date and Region into new_rows list.
        new_rows.append([region_ID,size_rank,region_name,region_type,state_name, date, value])

#New df based on new_rows 'list'
condensed_df = pd.DataFrame(new_rows, columns=
                             ['Region ID',
                              'Size Rank',
                              'Region Name',
                              'Region Type',
                              'State Name',
                              'Date',
                              metric_name])


#create moving average column for each Region.
window_size = 3 #time period (weeks)
condensed_df[f'{metric_name} Rolling Avg'] = condensed_df.groupby('Region Name')[metric_name].rolling(window=window_size).mean().reset_index(level=0, drop=True)

#preview df
condensed_df
# Out:
#        Region ID  Size Rank            Region Name Region Type State Name  \
# 0         102001          0          United States     country        NaN
# 1         102001          0          United States     country        NaN
# 2         102001          0          United States     country        NaN
# 3         102001          0          United States     country        NaN
# 4         102001          0          United States     country        NaN
# ...          ...        ...                    ...         ...        ...
# 28590     394685        289  Homosassa Springs, FL         msa         FL
# 28591     394685        289  Homosassa Springs, FL         msa         FL
# 28592     394685        289  Homosassa Springs, FL         msa         FL
# 28593     394685        289  Homosassa Springs, FL         msa         FL
# 28594     394685        289  Homosassa Springs, FL         msa         FL
#
#             Date  Units Sold Below List Price (%)  \
# 0     2018-01-06                         0.633396
# 1     2018-01-13                         0.642037
# 2     2018-01-20                         0.648973
# 3     2018-01-27                         0.655017
# 4     2018-02-03                         0.660971
# ...          ...                              ...
# 28590 2023-09-09                         0.750000
# 28591 2023-09-16                         0.657143
# 28592 2023-09-23                         0.659574
# 28593 2023-09-30                         0.672414
# 28594 2023-10-07                         0.690476
#
#        Units Sold Below List Price (%) Rolling Avg
# 0                                              NaN
# 1                                              NaN
# 2                                         0.641469
# 3                                         0.648676
# 4                                         0.654987
# ...                                            ...
# 28590                                     0.694444
# 28591                                     0.697118
# 28592                                     0.688906
# 28593                                     0.663044
# 28594                                     0.674155
#
# [28595 rows x 8 columns]

# %% [markdown]
# # Analysis Testing

# %% [markdown]
# Section I created to test initial clean dataframe. Use only as a referance for chart output.

# %%
MSA_filter = ['United States','New York, NY','Los Angeles, CA','Chicago, IL','Dallas, TX']

short_table = condensed_df['Region Name'].isin(MSA_filter)
filtered_df = condensed_df[short_table]

filtered_df
# Out:
#       Region ID  Size Rank    Region Name Region Type State Name       Date  \
# 0        102001          0  United States     country        NaN 2018-01-06
# 1        102001          0  United States     country        NaN 2018-01-13
# 2        102001          0  United States     country        NaN 2018-01-20
# 3        102001          0  United States     country        NaN 2018-01-27
# 4        102001          0  United States     country        NaN 2018-02-03
# ...         ...        ...            ...         ...        ...        ...
# 1500     394514          4     Dallas, TX         msa         TX 2023-09-09
# 1501     394514          4     Dallas, TX         msa         TX 2023-09-16
# 1502     394514          4     Dallas, TX         msa         TX 2023-09-23
# 1503     394514          4     Dallas, TX         msa         TX 2023-09-30
# 1504     394514          4     Dallas, TX         msa         TX 2023-10-07
#
#       Units Sold Below List Price (%)  \
# 0                            0.633396
# 1                            0.642037
# 2                            0.648973
# 3                            0.655017
# 4                            0.660971
# ...                               ...
# 1500                         0.538569
# 1501                         0.531646
# 1502                         0.537181
# 1503                         0.555657
# 1504                         0.565510
#
#       Units Sold Below List Price (%) Rolling Avg
# 0                                             NaN
# 1                                             NaN
# 2                                        0.641469
# 3                                        0.648676
# 4                                        0.654987
# ...                                           ...
# 1500                                     0.525325
# 1501                                     0.529078
# 1502                                     0.535799
# 1503                                     0.541494
# 1504                                     0.552782
#
# [1505 rows x 8 columns]

# %%
window_size = 3

for region, data in filtered_df.groupby('Region Name'):
    data.plot(kind='line', x='Date', y=metric_name, label=f'{region} - Original', figsize=(10, 6))
    plt.plot(data['Date'], data[f'{metric_name} Rolling Avg'], label=f'{region} - Moving Average')

    
plt.title('Line Chart with Moving Average by Region')
plt.xlabel('Month')
plt.ylabel(metric_name)
plt.legend()
plt.show()

# %% [markdown]
# # Generate Clean CSV File

# %%
#IMPORTANT -- CHANGE CSV OUTPUT NAME RELEVANT REPORT
condensed_df.to_csv(clean_csv_path, index=False)
