# %% [markdown]
# # Zillow CSV ETL process

# %% [markdown]
# This code serves as a blueprint for the csv ETL process. You will need to update certain field and column names in this report according to the csv file name, the metric and report under consideration, and so on. There are annotations provided throughout to guide you through the code.

# %%
# Dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# # Declare Variables

# %%
#Add inputs here, and clean csv should auto-populate
start_date = '2018-01-06'
end_date = '2023-11-04'
raw_csv_path = 'Resources_Raw/raw_mean_listings_price_cut_perc_week_all.csv'
clean_csv_path = 'Resources_Clean/clean_mean_listings_price_cut_perc_week_all.csv'
metric_name = 'Mean Listings Price Cut (%)'

# %%
initial_csv = Path(raw_csv_path)
initial_df = pd.read_csv(initial_csv)
initial_df
# Out:
#      RegionID  SizeRank            RegionName RegionType StateName  \
# 0      102001         0         United States    country       NaN
# 1      394913         1          New York, NY        msa        NY
# 2      753899         2       Los Angeles, CA        msa        CA
# 3      394463         3           Chicago, IL        msa        IL
# 4      394514         4            Dallas, TX        msa        TX
# ..        ...       ...                   ...        ...       ...
# 353    753920       569            Sonora, CA        msa        CA
# 354    394503       592         Corsicana, TX        msa        TX
# 355    394745       744  Kill Devil Hills, NC        msa        NC
# 356    786252       761            Bonham, TX        msa        TX
# 357    753871       811      Breckenridge, CO        msa        CO
#
#      2018-01-06  2018-01-13  2018-01-20  2018-01-27  2018-02-03  ...  \
# 0      0.036326    0.037157    0.036761    0.037030    0.036412  ...
# 1      0.041599    0.041929    0.042541    0.043552    0.043828  ...
# 2      0.031608    0.031473    0.031882    0.033334    0.031590  ...
# 3      0.031203    0.030694    0.030531    0.031077    0.031485  ...
# 4      0.026746    0.028362    0.026108    0.027396    0.026635  ...
# ..          ...         ...         ...         ...         ...  ...
# 353         NaN         NaN         NaN         NaN         NaN  ...
# 354         NaN         NaN         NaN         NaN         NaN  ...
# 355         NaN         NaN         NaN         NaN         NaN  ...
# 356         NaN         NaN         NaN         NaN         NaN  ...
# 357         NaN         NaN         NaN         NaN         NaN  ...
#
#      2023-09-02  2023-09-09  2023-09-16  2023-09-23  2023-09-30  2023-10-07  \
# 0      0.036183    0.035447    0.035561    0.035530    0.035619    0.035387
# 1      0.044334    0.045283    0.043963    0.042732    0.045417    0.044707
# 2      0.035844    0.037741    0.037082    0.037546    0.038734    0.035399
# 3      0.035994    0.034955    0.034684    0.033831    0.034148    0.033104
# 4      0.025945    0.026410    0.027018    0.027127    0.027400    0.026660
# ..          ...         ...         ...         ...         ...         ...
# 353         NaN         NaN         NaN         NaN    0.041458    0.032459
# 354         NaN         NaN         NaN         NaN         NaN         NaN
# 355    0.037202    0.034209    0.029874    0.024788    0.034213    0.039044
# 356         NaN         NaN         NaN         NaN         NaN         NaN
# 357         NaN         NaN         NaN         NaN         NaN         NaN
#
#      2023-10-14  2023-10-21  2023-10-28  2023-11-04
# 0      0.035562    0.035376    0.035121    0.035043
# 1      0.045375    0.043603    0.043790    0.043671
# 2      0.036803    0.037765    0.036738    0.037324
# 3      0.033802    0.032108    0.032822    0.033333
# 4      0.026481    0.026555    0.026616    0.026578
# ..          ...         ...         ...         ...
# 353    0.047325    0.035605    0.045600    0.039029
# 354         NaN         NaN    0.030597    0.033494
# 355    0.025068    0.038274    0.034037    0.032140
# 356         NaN         NaN    0.056267    0.042835
# 357         NaN         NaN         NaN    0.027687
#
# [358 rows x 310 columns]

# %% [markdown]
# # Remove Nulls from DataFrame

# %%
#Checks if any Date column has a null for a given RegionName
date_range_columns = initial_df.loc[:, start_date : end_date] 
null_check = date_range_columns.isna().any(axis=1)

#Reverse filter based on null check for rows without null
null_check_df = initial_df.loc[~null_check, :]

#Preview
null_check_df
# Out:
#      RegionID  SizeRank          RegionName RegionType StateName  2018-01-06  \
# 2      753899         2     Los Angeles, CA        msa        CA    0.031608
# 4      394514         4          Dallas, TX        msa        TX    0.026746
# 5      394692         5         Houston, TX        msa        TX    0.033959
# 6      395209         6      Washington, DC        msa        VA    0.031077
# 7      394974         7    Philadelphia, PA        msa        PA    0.038530
# 8      394856         8           Miami, FL        msa        FL    0.037481
# 10     394404        10          Boston, MA        msa        MA    0.035670
# 13     395025        13       Riverside, CA        msa        CA    0.030839
# 16     394865        16     Minneapolis, MN        msa        MN    0.031506
# 17     395056        17       San Diego, CA        msa        CA    0.026898
# 20     394358        20       Baltimore, MD        msa        MD    0.035791
# 21     395121        21       St. Louis, MO        msa        MO    0.036537
# 22     394943        22         Orlando, FL        msa        FL    0.027753
# 25     394998        25        Portland, OR        msa        OR    0.028708
# 26     395045        26      Sacramento, CA        msa        CA    0.026556
# 28     394466        28      Cincinnati, OH        msa        OH    0.038040
# 30     394775        30       Las Vegas, NV        msa        NV    0.026293
# 32     394492        32        Columbus, OH        msa        OH    0.031463
# 34     394475        35       Cleveland, OH        msa        OH    0.049567
# 37     395194        38  Virginia Beach, VA        msa        VA    0.027211
# 38     395005        39      Providence, RI        msa        RI    0.035716
# 43     394849        44         Memphis, TN        msa        TN    0.038993
# 44     395022        45        Richmond, VA        msa        VA    0.036835
# 45     394807        46      Louisville, KY        msa        KY    0.029464
# 53     395167        54          Tucson, AZ        msa        AZ    0.030950
# 54     753924        55  Urban Honolulu, HI        msa        HI    0.042880
# 55     395169        56           Tulsa, OK        msa        OK    0.030564
# 61     394312        62     Albuquerque, NM        msa        NM    0.022745
# 64     394753        65       Knoxville, TN        msa        TN    0.033388
# 72     753906        73      North Port, FL        msa        FL    0.029612
# 73     845158        74          Dayton, OH        msa        OH    0.033725
# 74     394457        75      Charleston, SC        msa        SC    0.026494
# 77     394440        78      Cape Coral, FL        msa        FL    0.029088
# 81     394766        82        Lakeland, FL        msa        FL    0.028601
# 89     394528        90         Deltona, FL        msa        FL    0.026235
# 96     394957        97        Palm Bay, FL        msa        FL    0.027875
# 110    394971       111       Pensacola, FL        msa        FL    0.029250
# 114    394995       115  Port St. Lucie, FL        msa        FL    0.032874
# 116    394898       117    Myrtle Beach, SC        msa        SC    0.028861
# 132    394658       133        Gulfport, MS        msa        MS    0.037037
# 7      0.038862    0.035178    0.036602
# 8      0.034464    0.034620    0.033805
# 10     0.040170    0.038664    0.038109
# 13     0.033387    0.033089    0.033107
# 16     0.033872    0.034482    0.033550
# 17     0.032877    0.033909    0.032151
# 20     0.035692    0.037929    0.036690
# 21     0.042495    0.041282    0.041297
# 22     0.028234    0.027089    0.028046
# 25     0.032553    0.033572    0.033836
# 26     0.031663    0.029875    0.030305
# 28     0.038396    0.037230    0.037465
# 30     0.023377    0.022781    0.020992
# 32     0.027634    0.026203    0.029678
# 34     0.043907    0.047662    0.043911
# 37     0.027473    0.026012    0.024742
# 38     0.041614    0.040479    0.042980
# 43     0.032329    0.030242    0.029866
# 44     0.034213    0.027711    0.029980
# 45     0.032906    0.029202    0.030732
# 53     0.028578    0.026652    0.029755
# 54     0.034332    0.035947    0.038926
# 55     0.033280    0.032642    0.032293
# 61     0.027041    0.027546    0.026896
# 64     0.032374    0.031314    0.031208
# 72     0.032027    0.031785    0.033197
# 73     0.033333    0.037303    0.033036
# 74     0.024414    0.026126    0.022408
# 77     0.032934    0.034254    0.034872
# 81     0.027142    0.027232    0.025667
# 89     0.030496    0.030760    0.032024
# 96     0.028550    0.028892    0.027852
# 110    0.033491    0.032409    0.032075
# 114    0.030259    0.029849    0.028431
# 116    0.027189    0.028279    0.028248
# 132    0.037974    0.035820    0.036137
# 148    0.030440    0.032900    0.032006
# 174    0.028683    0.031270    0.030706
#
# [42 rows x 310 columns]

# %% [markdown]
# # Condense Date Columns to Single Column

# %% [markdown]
# In this section, we condense the multiple date columns into a single 'date' column. This allows for easier data visualization moving forward.

# %%
condensed_rough_df = pd.DataFrame(null_check_df)

new_rows = []

#For loop to iterate through each RegionName
for _, row in condensed_rough_df.iterrows():
    region_ID = row['RegionID']
    size_rank = row['SizeRank']
    region_name = row['RegionName']
    region_type = row['RegionType']
    state_name = row['StateName']
    
    #For loop to iterate through each Date Column within a given RegionName
    for date_column in condensed_rough_df.columns[5:]:
        date = pd.to_datetime(date_column)
        value = row[date_column]
        
        #Add 'Date' and 'value' values for a given Date and Region into new_rows list.
        new_rows.append([region_ID,size_rank,region_name,region_type,state_name, date, value])

#New df based on new_rows 'list'
condensed_df = pd.DataFrame(new_rows, columns=
                             ['Region ID',
                              'Size Rank',
                              'Region Name',
                              'Region Type',
                              'State Name',
                              'Date',
                              metric_name])


#create moving average column for each Region.
window_size = 3 #time period (weeks)
condensed_df[f'{metric_name} Rolling Avg'] = condensed_df.groupby('Region Name')[metric_name].rolling(window=window_size).mean().reset_index(level=0, drop=True)

#preview df
condensed_df
# Out:
#        Region ID  Size Rank      Region Name Region Type State Name  \
# 0         753899          2  Los Angeles, CA         msa         CA
# 1         753899          2  Los Angeles, CA         msa         CA
# 2         753899          2  Los Angeles, CA         msa         CA
# 3         753899          2  Los Angeles, CA         msa         CA
# 4         753899          2  Los Angeles, CA         msa         CA
# ...          ...        ...              ...         ...        ...
# 12805     753875        176    Crestview, FL         msa         FL
# 12806     753875        176    Crestview, FL         msa         FL
# 12807     753875        176    Crestview, FL         msa         FL
# 12808     753875        176    Crestview, FL         msa         FL
# 12809     753875        176    Crestview, FL         msa         FL
#
#             Date  Mean Listings Price Cut (%)  \
# 0     2018-01-06                     0.031608
# 1     2018-01-13                     0.031473
# 2     2018-01-20                     0.031882
# 3     2018-01-27                     0.033334
# 4     2018-02-03                     0.031590
# ...          ...                          ...
# 12805 2023-10-07                     0.027787
# 12806 2023-10-14                     0.029682
# 12807 2023-10-21                     0.028683
# 12808 2023-10-28                     0.031270
# 12809 2023-11-04                     0.030706
#
#        Mean Listings Price Cut (%) Rolling Avg
# 0                                          NaN
# 1                                          NaN
# 2                                     0.031654
# 3                                     0.032229
# 4                                     0.032268
# ...                                        ...
# 12805                                 0.028195
# 12806                                 0.029576
# 12807                                 0.028717
# 12808                                 0.029878
# 12809                                 0.030220
#
# [12810 rows x 8 columns]

# %% [markdown]
# # Analysis Testing

# %% [markdown]
# Section I created to test initial clean dataframe. Use only as a referance for chart output.

# %%
MSA_filter = ['United States','New York, NY','Los Angeles, CA','Chicago, IL','Dallas, TX']

short_table = condensed_df['Region Name'].isin(MSA_filter)
filtered_df = condensed_df[short_table]

filtered_df
# Out:
#      Region ID  Size Rank      Region Name Region Type State Name       Date  \
# 0       753899          2  Los Angeles, CA         msa         CA 2018-01-06
# 1       753899          2  Los Angeles, CA         msa         CA 2018-01-13
# 2       753899          2  Los Angeles, CA         msa         CA 2018-01-20
# 3       753899          2  Los Angeles, CA         msa         CA 2018-01-27
# 4       753899          2  Los Angeles, CA         msa         CA 2018-02-03
# ..         ...        ...              ...         ...        ...        ...
# 605     394514          4       Dallas, TX         msa         TX 2023-10-07
# 606     394514          4       Dallas, TX         msa         TX 2023-10-14
# 607     394514          4       Dallas, TX         msa         TX 2023-10-21
# 608     394514          4       Dallas, TX         msa         TX 2023-10-28
# 609     394514          4       Dallas, TX         msa         TX 2023-11-04
#
#      Mean Listings Price Cut (%)  Mean Listings Price Cut (%) Rolling Avg
# 0                       0.031608                                      NaN
# 1                       0.031473                                      NaN
# 2                       0.031882                                 0.031654
# 3                       0.033334                                 0.032229
# 4                       0.031590                                 0.032268
# ..                           ...                                      ...
# 605                     0.026660                                 0.027062
# 606                     0.026481                                 0.026847
# 607                     0.026555                                 0.026565
# 608                     0.026616                                 0.026551
# 609                     0.026578                                 0.026583
#
# [610 rows x 8 columns]

# %%
window_size = 3

for region, data in filtered_df.groupby('Region Name'):
    data.plot(kind='line', x='Date', y=metric_name, label=f'{region} - Original', figsize=(10, 6))
    plt.plot(data['Date'], data[f'{metric_name} Rolling Avg'], label=f'{region} - Moving Average')

    
plt.title('Line Chart with Moving Average by Region')
plt.xlabel('Month')
plt.ylabel(metric_name)
plt.legend()
plt.show()

# %% [markdown]
# # Generate Clean CSV File

# %%
#IMPORTANT -- CHANGE CSV OUTPUT NAME RELEVANT REPORT
condensed_df.to_csv(clean_csv_path, index=False)
