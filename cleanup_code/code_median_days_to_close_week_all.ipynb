# %% [markdown]
# # Zillow CSV ETL process

# %% [markdown]
# This code serves as a blueprint for the csv ETL process. You will need to update certain field and column names in this report according to the csv file name, the metric and report under consideration, and so on. There are annotations provided throughout to guide you through the code.

# %%
# Dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# # Declare Variables

# %%
#Add inputs here, and clean csv should auto-populate
raw_csv_path = 'Resources_Raw/raw_median_days_to_close_week_all.csv'
clean_csv_path = 'Resources_Clean/clean_median_days_to_close_week_all.csv'
metric_name = 'Median Days to Close'

# %%
initial_csv = Path(raw_csv_path)
initial_df = pd.read_csv(initial_csv)
initial_df
# Out:
#      RegionID  SizeRank        RegionName RegionType StateName  2018-01-06  \
# 0      102001         0     United States    country       NaN        35.0
# 1      394913         1      New York, NY        msa        NY        62.0
# 2      753899         2   Los Angeles, CA        msa        CA        34.0
# 3      394463         3       Chicago, IL        msa        IL        43.0
# 4      394514         4        Dallas, TX        msa        TX        19.0
# ..        ...       ...               ...        ...       ...         ...
# 220    395086       402   Sevierville, TN        msa        TN         NaN
# 221    394410       408      Brainerd, MN        msa        MN         NaN
# 222    394928       410    Ocean City, NJ        msa        NJ         NaN
# 223    394674       467         Heber, UT        msa        UT         NaN
# 224    753871       811  Breckenridge, CO        msa        CO         NaN
#
#      2018-01-13  2018-01-20  2018-01-27  2018-02-03  ...  2023-08-05  \
# 0          35.0        37.0        35.0        33.0  ...        32.0
# 1          64.0        61.0        62.0        58.0  ...        54.0
# 2          34.0        36.0        35.0        33.0  ...        28.0
# 3          42.0        43.0        44.0        41.0  ...        37.0
# 4          20.0        22.0        19.0        19.0  ...        27.0
# ..          ...         ...         ...         ...  ...         ...
# 220         NaN         NaN         NaN         NaN  ...         NaN
# 221         NaN         NaN         NaN         NaN  ...        34.0
# 222         NaN         NaN         NaN         NaN  ...        40.0
# 223         NaN         NaN         NaN         NaN  ...         NaN
# 224         NaN         NaN         NaN         NaN  ...        29.0
#
#      2023-08-12  2023-08-19  2023-08-26  2023-09-02  2023-09-09  2023-09-16  \
# 0          30.0        31.0        31.0        31.0        31.0        31.0
# 1          54.0        52.0        56.0        50.0        52.0        51.0
# 2          28.0        27.0        28.0        27.0        28.0        28.0
# 3          34.0        33.0        34.0        35.0        34.0        35.0
# 4          26.0        27.0        27.0        27.0        27.0        28.0
# ..          ...         ...         ...         ...         ...         ...
# 220         NaN         NaN         NaN         NaN         NaN         NaN
# 221        31.0        29.0        31.0        25.0        32.0        35.0
# 222        35.0        30.0        35.0        39.0        36.0        37.0
# 223         NaN         NaN         NaN        23.0        22.0        28.0
# 224        33.0        31.0        35.0        33.0        30.0        33.0
#
#      2023-09-23  2023-09-30  2023-10-07
# 0          31.0        31.0        30.0
# 1          52.0        50.0        50.0
# 2          28.0        28.0        28.0
# 3          34.0        33.0        35.0
# 4          28.0        27.0        27.0
# ..          ...         ...         ...
# 220         NaN        29.0        30.0
# 221        32.0        38.0        30.0
# 222        34.0        37.0        37.0
# 223        28.0        27.0        25.0
# 224        29.0        30.0        31.0
#
# [225 rows x 306 columns]

# %% [markdown]
# # Remove Nulls from DataFrame

# %%
#Checks if any Date column has a null for a given RegionName

#looks at column range from 6th column to last column in df
date_columns_slice = initial_df.iloc[:, 5:-1]

#looks at every row in this column range, and checks for null values
date_range_columns = initial_df.loc[:,date_columns_slice.columns] 
null_check = date_range_columns.isna().any(axis=1)

#Reverse filter based on null check for rows without null
null_check_df = initial_df.loc[~null_check, :]

#Preview
null_check_df
# Out:
#      RegionID  SizeRank             RegionName RegionType StateName  \
# 0      102001         0          United States    country       NaN
# 1      394913         1           New York, NY        msa        NY
# 2      753899         2        Los Angeles, CA        msa        CA
# 4      394514         4             Dallas, TX        msa        TX
# 5      394692         5            Houston, TX        msa        TX
# 6      395209         6         Washington, DC        msa        VA
# 7      394974         7       Philadelphia, PA        msa        PA
# 9      394347         9            Atlanta, GA        msa        GA
# 10     394404        10             Boston, MA        msa        MA
# 12     395057        12      San Francisco, CA        msa        CA
# 13     395025        13          Riverside, CA        msa        CA
# 16     394865        16        Minneapolis, MN        msa        MN
# 25     394998        25           Portland, OR        msa        OR
# 26     395045        26         Sacramento, CA        msa        CA
# 28     394466        28         Cincinnati, OH        msa        OH
# 31     394735        31        Kansas City, MO        msa        MO
# 32     394492        32           Columbus, OH        msa        OH
# 33     394705        34       Indianapolis, IN        msa        IN
# 39     394714        40       Jacksonville, FL        msa        FL
# 42     395012        43            Raleigh, NC        msa        NC
# 49     394425        50            Buffalo, NY        msa        NY
# 50     394388        51         Birmingham, AL        msa        AL
# 51     395031        52          Rochester, NY        msa        NY
# 53     395167        54             Tucson, AZ        msa        AZ
# 57     395238        58          Worcester, MA        msa        MA
# 61     394312        62        Albuquerque, NM        msa        NM
# 63     394308        64             Albany, NY        msa        NY
# 64     394753        65          Knoxville, TN        msa        TN
# 70     394952        71             Oxnard, CA        msa        CA
# 73     845158        74             Dayton, OH        msa        OH
# 74     394457        75         Charleston, SC        msa        SC
# 75     394648        76         Greensboro, NC        msa        NC
# 76     395134        77           Stockton, CA        msa        CA
# 77     394440        78         Cape Coral, FL        msa        FL
# 83     394531        84         Des Moines, IA        msa        IA
# 84     395115        85        Springfield, MA        msa        MA
# 92     395160        93             Toledo, OH        msa        OH
# 93     394549        95             Durham, NC        msa        NC
# 101    394871       103            Modesto, CA        msa        CA
# 105    394770       107            Lansing, MI        msa        MI
# 106    394589       109       Fayetteville, NC        msa        NC
# 107    394792       110          Lexington, KY        msa        KY
# 109    395068       112         Santa Rosa, CA        msa        CA
# 114    394898       117       Myrtle Beach, SC        msa        SC
# 115    395116       118        Springfield, MO        msa        MO
# 117    394746       120            Killeen, TX        msa        TX
# 125    394502       129     Corpus Christi, TX        msa        TX
# 129    394596       135              Flint, MI        msa        MI
# 130    394972       136             Peoria, IL        msa        IL
# 138    394576       146             Eugene, OR        msa        OR
# 139    394901       147             Naples, FL        msa        FL
# 141    394927       149              Ocala, FL        msa        FL
# 157    394937       172            Olympia, WA        msa        WA
# 164    394412       181          Bremerton, WA        msa        WA
# 174    845160       198    Prescott Valley, AZ        msa        AZ
# 176    394361       202    Barnstable Town, MA        msa        MA
# 193    394380       232               Bend, OR        msa        OR
# 196    395009       237        Punta Gorda, FL        msa        FL
# 210    394685       289  Homosassa Springs, FL        msa        FL
#
#      2018-01-06  2018-01-13  2018-01-20  2018-01-27  2018-02-03  ...  \
# 0          35.0        35.0        37.0        35.0        33.0  ...
# 1          62.0        64.0        61.0        62.0        58.0  ...
# 2          34.0        34.0        36.0        35.0        33.0  ...
# 1          51.0        52.0        50.0        50.0
# 2          28.0        28.0        28.0        28.0
# 4          28.0        28.0        27.0        27.0
# 5          29.0        28.0        28.0        28.0
# 6          28.0        28.0        28.0        25.0
# 7          35.0        34.0        35.0        34.0
# 9          25.0        25.0        23.0        21.0
# 10         39.0        40.0        38.0        37.0
# 12         22.0        23.0        22.0        22.0
# 13         29.0        30.0        28.0        29.0
# 16         28.0        27.0        28.0        26.0
# 25         30.0        29.0        28.0        28.0
# 26         24.0        23.0        25.0        23.0
# 28         28.0        25.0        28.0        28.0
# 31         31.0        30.0        31.0        31.0
# 32         29.0        29.0        29.0        28.0
# 33         30.0        31.0        31.0        30.0
# 39         23.0        22.0        24.0        23.0
# 42         31.0        32.0        32.0        33.0
# 49         59.0        59.0        59.0        60.0
# 50         28.0        28.0        28.0        24.0
# 51         47.0        47.0        45.0        45.0
# 53         30.0        30.0        31.0        29.0
# 57         39.0        39.0        40.0        37.0
# 61         33.0        33.0        33.0        32.0
# 63         49.0        51.0        51.0        49.0
# 64         30.0        30.0        31.0        30.0
# 70         29.0        29.0        27.0        29.0
# 73         31.0        30.0        29.0        28.0
# 74         34.0        33.0        31.0        33.0
# 75         32.0        32.0        32.0        31.0
# 76         27.0        29.0        26.0        27.0
# 77         30.0        29.0        31.0        28.0
# 83         36.0        33.0        34.0        36.0
# 84         37.0        42.0        39.0        34.0
# 92         31.0        28.0        30.0        29.0
# 93         33.0        30.0        31.0        32.0
# 101        25.0        27.0        30.0        28.0
# 105        30.0        31.0        30.0        31.0
# 106        34.0        34.0        32.0        32.0
# 107        33.0        32.0        31.0        31.0
# 109        19.0        21.0        21.0        21.0
# 114        35.0        35.0        34.0        35.0
# 115        35.0        31.0        32.0        30.0
# 117        33.0        31.0        30.0        31.0
# 125        31.0        31.0        31.0        30.0
# 129        28.0        25.0        29.0        28.0
# 130        34.0        32.0        32.0        30.0
# 138        30.0        25.0        27.0        30.0
# 139        37.0        35.0        34.0        35.0
# 141        33.0        32.0        32.0        34.0
# 157        30.0        28.0        30.0        30.0
# 164        28.0        28.0        31.0        29.0
# 174        30.0        30.0        30.0        26.0
# 176        45.0        43.0        44.0        38.0
# 193        30.0        34.0        31.0        32.0
# 196        34.0        34.0        33.0        28.0
# 210        33.0        36.0        33.0        32.0
#
# [59 rows x 306 columns]

# %% [markdown]
# # Condense Date Columns to Single Column

# %% [markdown]
# In this section, we condense the multiple date columns into a single 'date' column. This allows for easier data visualization moving forward.

# %%
condensed_rough_df = pd.DataFrame(null_check_df)

new_rows = []

#For loop to iterate through each RegionName
for _, row in condensed_rough_df.iterrows():
    region_ID = row['RegionID']
    size_rank = row['SizeRank']
    region_name = row['RegionName']
    region_type = row['RegionType']
    state_name = row['StateName']
    
    #For loop to iterate through each Date Column within a given RegionName
    for date_column in condensed_rough_df.columns[5:]:
        date = pd.to_datetime(date_column)
        value = row[date_column]
        
        #Add 'Date' and 'value' values for a given Date and Region into new_rows list.
        new_rows.append([region_ID,size_rank,region_name,region_type,state_name, date, value])

#New df based on new_rows 'list'
condensed_df = pd.DataFrame(new_rows, columns=
                             ['Region ID',
                              'Size Rank',
                              'Region Name',
                              'Region Type',
                              'State Name',
                              'Date',
                              metric_name])


#create moving average column for each Region.
window_size = 3 #time period (weeks)
condensed_df[f'{metric_name} Rolling Avg'] = condensed_df.groupby('Region Name')[metric_name].rolling(window=window_size).mean().reset_index(level=0, drop=True)

#preview df
condensed_df
# Out:
#        Region ID  Size Rank            Region Name Region Type State Name  \
# 0         102001          0          United States     country        NaN
# 1         102001          0          United States     country        NaN
# 2         102001          0          United States     country        NaN
# 3         102001          0          United States     country        NaN
# 4         102001          0          United States     country        NaN
# ...          ...        ...                    ...         ...        ...
# 17754     394685        289  Homosassa Springs, FL         msa         FL
# 17755     394685        289  Homosassa Springs, FL         msa         FL
# 17756     394685        289  Homosassa Springs, FL         msa         FL
# 17757     394685        289  Homosassa Springs, FL         msa         FL
# 17758     394685        289  Homosassa Springs, FL         msa         FL
#
#             Date  Median Days to Close  Median Days to Close Rolling Avg
# 0     2018-01-06                  35.0                               NaN
# 1     2018-01-13                  35.0                               NaN
# 2     2018-01-20                  37.0                         35.666667
# 3     2018-01-27                  35.0                         35.666667
# 4     2018-02-03                  33.0                         35.000000
# ...          ...                   ...                               ...
# 17754 2023-09-09                  27.0                         32.666667
# 17755 2023-09-16                  33.0                         32.333333
# 17756 2023-09-23                  36.0                         32.000000
# 17757 2023-09-30                  33.0                         34.000000
# 17758 2023-10-07                  32.0                         33.666667
#
# [17759 rows x 8 columns]

# %% [markdown]
# # Analysis Testing

# %% [markdown]
# Section I created to test initial clean dataframe. Use only as a referance for chart output.

# %%
MSA_filter = ['United States','New York, NY','Los Angeles, CA','Chicago, IL','Dallas, TX']

short_table = condensed_df['Region Name'].isin(MSA_filter)
filtered_df = condensed_df[short_table]

filtered_df
# Out:
#       Region ID  Size Rank    Region Name Region Type State Name       Date  \
# 0        102001          0  United States     country        NaN 2018-01-06
# 1        102001          0  United States     country        NaN 2018-01-13
# 2        102001          0  United States     country        NaN 2018-01-20
# 3        102001          0  United States     country        NaN 2018-01-27
# 4        102001          0  United States     country        NaN 2018-02-03
# ...         ...        ...            ...         ...        ...        ...
# 1199     394514          4     Dallas, TX         msa         TX 2023-09-09
# 1200     394514          4     Dallas, TX         msa         TX 2023-09-16
# 1201     394514          4     Dallas, TX         msa         TX 2023-09-23
# 1202     394514          4     Dallas, TX         msa         TX 2023-09-30
# 1203     394514          4     Dallas, TX         msa         TX 2023-10-07
#
#       Median Days to Close  Median Days to Close Rolling Avg
# 0                     35.0                               NaN
# 1                     35.0                               NaN
# 2                     37.0                         35.666667
# 3                     35.0                         35.666667
# 4                     33.0                         35.000000
# ...                    ...                               ...
# 1199                  27.0                         27.000000
# 1200                  28.0                         27.333333
# 1201                  28.0                         27.666667
# 1202                  27.0                         27.666667
# 1203                  27.0                         27.333333
#
# [1204 rows x 8 columns]

# %%
window_size = 3

for region, data in filtered_df.groupby('Region Name'):
    data.plot(kind='line', x='Date', y=metric_name, label=f'{region} - Original', figsize=(10, 6))
    plt.plot(data['Date'], data[f'{metric_name} Rolling Avg'], label=f'{region} - Moving Average')

    
plt.title('Line Chart with Moving Average by Region')
plt.xlabel('Month')
plt.ylabel(metric_name)
plt.legend()
plt.show()

# %% [markdown]
# # Generate Clean CSV File

# %%
#IMPORTANT -- CHANGE CSV OUTPUT NAME RELEVANT REPORT
condensed_df.to_csv(clean_csv_path, index=False)
