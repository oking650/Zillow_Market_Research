# %%
# Dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
days_pending_temperature_csv = 'Resources_Clean/clean_temperature_cities.csv'

days_to_pending_temperature_df = pd.read_csv(days_pending_temperature_csv)

# %%
days_to_pending_temperature_df.head()
# Out:
#    Unnamed: 0  Region ID  Size Rank   Region Name Region Type State Name  \
# 0           0     394913          1  New York, NY         msa         NY
# 1           1     394913          1  New York, NY         msa         NY
# 2           2     394913          1  New York, NY         msa         NY
# 3           3     394913          1  New York, NY         msa         NY
# 4           4     394913          1  New York, NY         msa         NY
#
#          Date  Median Days Pending  Median Days Pending Rolling Avg  \
# 0  2019-12-07                 70.0                        67.333333
# 1  2019-12-14                 76.0                        71.666667
# 2  2019-12-21                 72.0                        72.666667
# 3  2019-12-28                 80.0                        76.000000
# 4  2020-01-04                 84.0                        78.666667
#
#           ID      Name State Country  Longitude   Latitude     full_name  \
# 0  5128638.0  New York    NY      US -75.499901  43.000351  New York, NY
# 1  5128638.0  New York    NY      US -75.499901  43.000351  New York, NY
# 2  5128638.0  New York    NY      US -75.499901  43.000351  New York, NY
# 3  5128638.0  New York    NY      US -75.499901  43.000351  New York, NY
# 4  5128638.0  New York    NY      US -75.499901  43.000351  New York, NY
#
#    Temperature  Temperature (Farenheit)
# 0     269.9300                   26.204
# 1     275.8075                   36.784
# 2     261.2150                   10.517
# 3     278.0075                   40.744
# 4     278.7225                   42.030

# %%
merged_reduced = days_to_pending_temperature_df[['Region ID',
                             'Size Rank',
                             'Region Name',
                             'Region Type',
                             'State Name',
                             'Date',
                             'Median Days Pending',
                             'Median Days Pending Rolling Avg',
                             'Longitude',
                             'Latitude',
                             'Temperature',
                             'Temperature (Farenheit)']]

merged_reduced = merged_reduced.rename(columns = {
                             'Median Days Pending':'Median Days to Pending',
                             'Median Days Pending Rolling Avg':'Median Days to Pending Rolling Avg',
                             'Temperature':'Temperature (Kelvin)'})

merged_reduced
# Out:
#      Region ID  Size Rank   Region Name Region Type State Name        Date  \
# 0       394913          1  New York, NY         msa         NY  2019-12-07
# 1       394913          1  New York, NY         msa         NY  2019-12-14
# 2       394913          1  New York, NY         msa         NY  2019-12-21
# 3       394913          1  New York, NY         msa         NY  2019-12-28
# 4       394913          1  New York, NY         msa         NY  2020-01-04
# ..         ...        ...           ...         ...        ...         ...
# 961     394347          9   Atlanta, GA         msa         GA  2022-12-03
# 962     394347          9   Atlanta, GA         msa         GA  2022-12-10
# 963     394347          9   Atlanta, GA         msa         GA  2022-12-17
# 964     394347          9   Atlanta, GA         msa         GA  2022-12-24
# 965     394347          9   Atlanta, GA         msa         GA  2022-12-31
#
#      Median Days to Pending  Median Days to Pending Rolling Avg  Longitude  \
# 0                      70.0                           67.333333 -75.499901
# 1                      76.0                           71.666667 -75.499901
# 2                      72.0                           72.666667 -75.499901
# 3                      80.0                           76.000000 -75.499901
# 4                      84.0                           78.666667 -75.499901
# ..                      ...                                 ...        ...
# 961                    32.0                           28.666667 -84.387978
# 962                    33.0                           31.000000 -84.387978
# 963                    35.0                           33.333333 -84.387978
# 964                    35.0                           34.333333 -84.387978
# 965                    42.0                           37.333333 -84.387978
#
#       Latitude  Temperature (Kelvin)  Temperature (Farenheit)
# 0    43.000351              269.9300                   26.204
# 1    43.000351              275.8075                   36.784
# 2    43.000351              261.2150                   10.517
# 3    43.000351              278.0075                   40.744
# 4    43.000351              278.7225                   42.030
# ..         ...                   ...                      ...
# 961  33.749001              284.7525                   52.885
# 962  33.749001              286.4225                   55.891
# 963  33.749001              280.1575                   44.614
# 964  33.749001              261.7900                   11.552
# 965  33.749001              287.1700                   57.236
#
# [966 rows x 12 columns]

# %%
merged_reduced['Date'] = pd.to_datetime(merged_reduced['Date'])

# %%
merged_top_size.pivot(index='Date', columns='Region Name', values='Median Days to Pending').plot(kind='line')
merged_top_size.pivot
plt.title('Median Days to Pending Over Time by Region')
plt.xlabel('Date')
plt.ylabel('Median Days to Pending')
plt.legend(title='Region Name', bbox_to_anchor=(1.05, 1), loc='upper left')  # Adjust legend position
plt.show()

# %%
merged_top_size.pivot
# Out:
# <bound method DataFrame.pivot of      Region ID  Size Rank   Region Name Region Type State Name       Date  \
# 0       394913          1  New York, NY         msa         NY 2019-12-07
# 1       394913          1  New York, NY         msa         NY 2019-12-14
# 2       394913          1  New York, NY         msa         NY 2019-12-21
# 3       394913          1  New York, NY         msa         NY 2019-12-28
# 4       394913          1  New York, NY         msa         NY 2020-01-04
# ..         ...        ...           ...         ...        ...        ...
# 961     394347          9   Atlanta, GA         msa         GA 2022-12-03
# 962     394347          9   Atlanta, GA         msa         GA 2022-12-10
# 963     394347          9   Atlanta, GA         msa         GA 2022-12-17
# 964     394347          9   Atlanta, GA         msa         GA 2022-12-24
# 965     394347          9   Atlanta, GA         msa         GA 2022-12-31
#
#      Median Days to Pending  Median Days to Pending Rolling Avg  Longitude  \
# 0                      70.0                           67.333333 -75.499901
# 1                      76.0                           71.666667 -75.499901
# 2                      72.0                           72.666667 -75.499901
# 3                      80.0                           76.000000 -75.499901
# 4                      84.0                           78.666667 -75.499901
# ..                      ...                                 ...        ...
# 961                    32.0                           28.666667 -84.387978
# 962                    33.0                           31.000000 -84.387978
# 963                    35.0                           33.333333 -84.387978
# 964                    35.0                           34.333333 -84.387978
# 965                    42.0                           37.333333 -84.387978
#
#       Latitude  Temperature (Kelvin)  Temperature (Farenheit)
# 0    43.000351              269.9300                   26.204
# 1    43.000351              275.8075                   36.784
# 2    43.000351              261.2150                   10.517
# 3    43.000351              278.0075                   40.744
# 4    43.000351              278.7225                   42.030
# ..         ...                   ...                      ...
# 961  33.749001              284.7525                   52.885
# 962  33.749001              286.4225                   55.891
# 963  33.749001              280.1575                   44.614
# 964  33.749001              261.7900                   11.552
# 965  33.749001              287.1700                   57.236
#
# [966 rows x 12 columns]>

# %%
merged_top_size.pivot(index='Date', columns='Region Name', values='Temperature (Farenheit)').plot(kind='line')
plt.title('Temperature (Farenheit) Over Time by Region')
plt.xlabel('Date')
plt.ylabel('Temperature (Farenheit)')
plt.legend(title='Region Name', bbox_to_anchor=(1.05, 1), loc='upper left')  # Adjust legend position
plt.show()

# %%
correlation = merged_reduced['Temperature (Farenheit)'].corr(merged_reduced['Median Days to Pending'])

print(f"Correlation between Median Sale to List Ratio and Median Days to Pending: {correlation}")
# Out:
# Correlation between Median Sale to List Ratio and Median Days to Pending: -0.3234257513365829

# %%
# Selecting columns for linear regression
x = merged_reduced['Temperature (Farenheit)']
y = merged_reduced['Median Days to Pending']

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Print the regression results
print(f"Slope: {slope}")
print(f"Intercept: {intercept}")
print(f"R-squared: {r_value**2}")
print(f"P-value: {p_value}")
print(f"Standard Error: {std_err}")
# Out:
# Slope: -0.24665300443245378
# Intercept: 35.98314168844884
# R-squared: 0.10460421662763324
# P-value: 5.854626054109514e-25
# Standard Error: 0.02324239189534806

# %%
plt.scatter(merged_reduced['Median Days to Pending'], merged_reduced['Temperature (Farenheit)'], alpha=0.5)
plt.title('Scatter Plot: Median Days to Pending vs. Temperature (Farenheit)')
plt.xlabel('Median Days to Pending')
plt.ylabel('Median Sale Temperature (Farenheit)')
plt.show()
